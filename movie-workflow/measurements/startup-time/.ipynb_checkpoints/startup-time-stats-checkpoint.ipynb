# %% [markdown]
# # Loading and visualizing data
# ***

# %%
# Imports
import ast
import pandas as pd

# Add old measures or not
old_measures = True

# Loading data
no_opa_data = []
with open("movie-wfs-no-opa-startup-time.dat", 'r') as f:
    for line in f:
        no_opa_data.append(ast.literal_eval(line))

if old_measures:
    with open("movie-wfs-no-opa-startup-time.dat", 'r') as f:
        for line in f:
            no_opa_data.append(ast.literal_eval(line))


opa_data = []
with open("movie-wfs-opa-startup-time.dat", 'r') as f:
    for line in f:
        opa_data.append(ast.literal_eval(line))


# Loading data into DataFrames
df_no_opa = pd.DataFrame(no_opa_data, columns=['name', 'pod_scheduled', 'initialized', 'containers_ready', 'ready', 'startup'])
df_opa = pd.DataFrame(opa_data, columns=['name', 'pod_scheduled', 'initialized', 'containers_ready', 'ready', 'startup'])


# Convert 'startup' to integers
df_no_opa['startup'] = df_no_opa['startup'].astype(int)
df_opa['startup'] = df_opa['startup'].astype(int)

# %%
# Printing NO OPA DataFrame
df_no_opa
# Out:
#        name         pod_scheduled           initialized      containers_ready  \
# 0     owner  2020-09-03T15:57:04Z  2020-09-03T15:57:06Z  2020-09-03T15:57:10Z
# 1     vfx-1  2020-09-03T15:57:07Z  2020-09-03T15:57:10Z  2020-09-03T15:57:13Z
# 2     vfx-2  2020-09-03T15:57:42Z  2020-09-03T15:57:44Z  2020-09-03T15:57:47Z
# 3     vfx-3  2020-09-03T15:58:20Z  2020-09-03T15:58:22Z  2020-09-03T15:58:25Z
# 4     color  2020-09-03T15:59:00Z  2020-09-03T15:59:02Z  2020-09-03T15:59:05Z
# ...     ...                   ...                   ...                   ...
# 1769  vfx-3  2020-09-03T21:41:30Z  2020-09-03T21:41:31Z  2020-09-03T21:41:36Z
# 1770  color  2020-09-03T21:42:04Z  2020-09-03T21:42:06Z  2020-09-03T21:42:10Z
# 1771  sound  2020-09-03T21:42:40Z  2020-09-03T21:42:43Z  2020-09-03T21:42:47Z
# 1772    hdr  2020-09-03T21:43:26Z  2020-09-03T21:43:29Z  2020-09-03T21:43:33Z
# 1773  owner  2020-09-03T21:44:54Z  2020-09-03T21:44:56Z  2020-09-03T21:45:01Z
#
#                      ready  startup
# 0     2020-09-03T15:57:10Z        6
# 1     2020-09-03T15:57:13Z        6
# 2     2020-09-03T15:57:47Z        5
# 3     2020-09-03T15:58:25Z        5
# 4     2020-09-03T15:59:05Z        5
# ...                    ...      ...
# 1769  2020-09-03T21:41:36Z        6
# 1770  2020-09-03T21:42:10Z        6
# 1771  2020-09-03T21:42:47Z        7
# 1772  2020-09-03T21:43:33Z        7
# 1773  2020-09-03T21:45:01Z        7
#
# [1774 rows x 6 columns]

# %%
# Describe DataFrame
df_no_opa.describe()
# Out:
#            startup
# count  1774.000000
# mean      5.943630
# std       0.876581
# min       4.000000
# 25%       5.000000
# 50%       6.000000
# 75%       7.000000
# max      11.000000

# %%
# Printing OPA DataFrame
df_opa
# Out:
#        name         pod_scheduled           initialized      containers_ready  \
# 0     owner  2020-06-10T19:36:38Z  2020-06-10T19:36:41Z  2020-06-10T19:36:46Z
# 1     vfx-1  2020-06-10T19:36:42Z  2020-06-10T19:36:45Z  2020-06-10T19:36:51Z
# 2     vfx-2  2020-06-10T19:37:21Z  2020-06-10T19:37:24Z  2020-06-10T19:37:29Z
# 3     vfx-3  2020-06-10T19:38:02Z  2020-06-10T19:38:05Z  2020-06-10T19:38:11Z
# 4     color  2020-06-10T19:38:38Z  2020-06-10T19:38:40Z  2020-06-10T19:38:45Z
# ...     ...                   ...                   ...                   ...
# 1083    hdr  2020-06-15T16:32:15Z  2020-06-15T16:32:17Z  2020-06-15T16:32:22Z
# 1084  owner  2020-06-15T16:33:28Z  2020-06-15T16:33:30Z  2020-06-15T16:33:36Z
# 1085  color  2020-06-15T16:33:32Z  2020-06-15T16:33:35Z  2020-06-15T16:33:39Z
# 1086    hdr  2020-06-15T16:34:15Z  2020-06-15T16:34:17Z  2020-06-15T16:34:24Z
# 1087  owner  2020-06-15T16:35:28Z  2020-06-15T16:35:31Z  2020-06-15T16:35:36Z
#
#                      ready  startup
# 0     2020-06-10T19:36:46Z        8
# 1     2020-06-10T19:36:51Z        9
# 2     2020-06-10T19:37:29Z        8
# 3     2020-06-10T19:38:11Z        9
# 4     2020-06-10T19:38:45Z        7
# ...                    ...      ...
# 1083  2020-06-15T16:32:22Z        7
# 1084  2020-06-15T16:33:36Z        8
# 1085  2020-06-15T16:33:39Z        7
# 1086  2020-06-15T16:34:24Z        9
# 1087  2020-06-15T16:35:36Z        8
#
# [1088 rows x 6 columns]

# %%
# Describe DataFrame
df_opa.describe()
# Out:
#            startup
# count  1088.000000
# mean      7.834559
# std       1.026879
# min       5.000000
# 25%       7.000000
# 50%       8.000000
# 75%       8.000000
# max      14.000000

# %% [markdown]
# # Filtering DataFrames by pod
# ***

# %%
# NO OPA filters
no_opa_is_owner = df_no_opa['name'] == "owner"
no_opa_is_vfx_1 = df_no_opa['name'] == "vfx-1"
no_opa_is_vfx_2 = df_no_opa['name'] == "vfx-2"
no_opa_is_vfx_3 = df_no_opa['name'] == "vfx-3"
no_opa_is_color = df_no_opa['name'] == "color"
no_opa_is_sound = df_no_opa['name'] == "sound"
no_opa_is_hdr   = df_no_opa['name'] == "hdr"

# Filtered DataFrames by pod
df_no_opa_owner = df_no_opa[no_opa_is_owner]
df_no_opa_vfx_1 = df_no_opa[no_opa_is_vfx_1]
df_no_opa_vfx_2 = df_no_opa[no_opa_is_vfx_2]
df_no_opa_vfx_3 = df_no_opa[no_opa_is_vfx_3]
df_no_opa_color = df_no_opa[no_opa_is_color]
df_no_opa_sound = df_no_opa[no_opa_is_sound]
df_no_opa_hdr   = df_no_opa[no_opa_is_hdr]

dfs_no_opa_pods = [df_no_opa_owner, df_no_opa_vfx_1, df_no_opa_vfx_2, df_no_opa_vfx_3, df_no_opa_color, df_no_opa_sound, df_no_opa_hdr]


# OPA filters
opa_is_owner = df_opa['name'] == "owner"
opa_is_vfx_1 = df_opa['name'] == "vfx-1"
opa_is_vfx_2 = df_opa['name'] == "vfx-2"
opa_is_vfx_3 = df_opa['name'] == "vfx-3"
opa_is_color = df_opa['name'] == "color"
opa_is_sound = df_opa['name'] == "sound"
opa_is_hdr   = df_opa['name'] == "hdr"

# Filtered DataFrames by pod
df_opa_owner = df_opa[opa_is_owner]
df_opa_vfx_1 = df_opa[opa_is_vfx_1]
df_opa_vfx_2 = df_opa[opa_is_vfx_2]
df_opa_vfx_3 = df_opa[opa_is_vfx_3]
df_opa_color = df_opa[opa_is_color]
df_opa_sound = df_opa[opa_is_sound]
df_opa_hdr   = df_opa[opa_is_hdr]

dfs_opa_pods = [df_opa_owner, df_opa_vfx_1, df_opa_vfx_2, df_opa_vfx_3, df_opa_color, df_opa_sound, df_opa_hdr]

# %%
# Describe each DataFrame per Pod
for df in dfs_opa_pods:
    print(df.iat[0,0])
    print(df.describe())
    print('\n')
# Out:
# owner
#           startup
# count  157.000000
# mean     7.445860
# std      1.027786
# min      5.000000
# 25%      7.000000
# 50%      7.000000
# 75%      8.000000
# max     14.000000
#
#
# vfx-1
#           startup
# count  138.000000
# mean     8.173913
# std      1.003010
# min      6.000000
# 25%      8.000000
# 50%      8.000000
# 75%      9.000000
# max     12.000000
#
#
# vfx-2
#          startup
# count  135.00000
# mean     8.22963
# std      1.05052
# min      6.00000
# 25%      8.00000
# 50%      8.00000
# 75%      9.00000
# max     11.00000
#
#
# vfx-3
#           startup
# count  135.000000
# mean     8.451852
# std      0.990391
# min      6.000000
# 25%      8.000000
# 50%      8.000000
# 75%      9.000000
# max     11.000000
#
#
# color
#           startup
# count  257.000000
# mean     7.478599
# std      0.918840
# min      5.000000
# 25%      7.000000
# 50%      7.000000
# 75%      8.000000
# max     10.000000
#
#
# sound
#           startup
# count  130.000000
# mean     7.830769
# std      0.899082
# min      6.000000
# 25%      7.000000
# 50%      8.000000
# 75%      8.000000
# max     10.000000
#
#
# hdr
#           startup
# count  136.000000
# mean     7.610294
# std      0.827068
# min      6.000000
# 25%      7.000000
# 50%      8.000000
# 75%      8.000000
# max     10.000000

# %%
# Describe each DataFrame per Pod
for df in dfs_no_opa_pods:
    print(df.iat[0,0])
    print(df.describe())
    print('\n')
# Out:
# owner
#           startup
# count  300.000000
# mean     6.146667
# std      0.829124
# min      5.000000
# 25%      6.000000
# 50%      6.000000
# 75%      7.000000
# max      9.000000
#
#
# vfx-1
#           startup
# count  210.000000
# mean     5.895238
# std      0.769313
# min      4.000000
# 25%      5.000000
# 50%      6.000000
# 75%      6.000000
# max      7.000000
#
#
# vfx-2
#           startup
# count  210.000000
# mean     5.552381
# std      0.705155
# min      4.000000
# 25%      5.000000
# 50%      5.000000
# 75%      6.000000
# max      7.000000
#
#
# vfx-3
#           startup
# count  202.000000
# mean     5.396040
# std      0.786442
# min      4.000000
# 25%      5.000000
# 50%      5.000000
# 75%      6.000000
# max      7.000000
#
#
# color
#           startup
# count  376.000000
# mean     5.771277
# std      0.727241
# min      4.000000
# 25%      5.000000
# 50%      6.000000
# 75%      6.000000
# max      7.000000
#
#
# sound
#           startup
# count  200.000000
# mean     6.340000
# std      1.043958
# min      4.000000
# 25%      6.000000
# 50%      6.000000
# 75%      7.000000
# max     11.000000
#
#
# hdr
#           startup
# count  276.000000
# mean     6.405797
# std      0.814752
# min      5.000000
# 25%      6.000000
# 50%      6.000000
# 75%      7.000000
# max      8.000000

# %% [markdown]
# # Matching sample sizes across DataFrames
# ***

# %%
equal_sample_size = 130

# Adjust sample sizes for comparison
df_no_opa_owner = df_no_opa_owner.head(equal_sample_size)
df_no_opa_vfx_1 = df_no_opa_vfx_1.head(equal_sample_size)
df_no_opa_vfx_2 = df_no_opa_vfx_2.head(equal_sample_size)
df_no_opa_vfx_3 = df_no_opa_vfx_3.head(equal_sample_size)
df_no_opa_color = df_no_opa_color.head(equal_sample_size)
df_no_opa_sound = df_no_opa_sound.head(equal_sample_size)
df_no_opa_hdr   = df_no_opa_hdr.head(equal_sample_size)

df_opa_owner = df_opa_owner.head(equal_sample_size)
df_opa_vfx_1 = df_opa_vfx_1.head(equal_sample_size)
df_opa_vfx_2 = df_opa_vfx_2.head(equal_sample_size)
df_opa_vfx_3 = df_opa_vfx_3.head(equal_sample_size)
df_opa_color = df_opa_color.head(equal_sample_size)
df_opa_sound = df_opa_sound.head(equal_sample_size)
df_opa_hdr   = df_opa_hdr.head(equal_sample_size)

dfs_opa_pods = [df_opa_owner, df_opa_vfx_1, df_opa_vfx_2, df_opa_vfx_3, df_opa_color, df_opa_sound, df_opa_hdr]
dfs_no_opa_pods = [df_no_opa_owner, df_no_opa_vfx_1, df_no_opa_vfx_2, df_no_opa_vfx_3, df_no_opa_color, df_no_opa_sound, df_no_opa_hdr]

# Verify shapes of DataFrames
for dfs in dfs_no_opa_pods:
    print(dfs.shape)

for dfs in dfs_opa_pods:
    print(dfs.shape)


## No OPA data in one DataFrame
df_no_opa_resized = pd.DataFrame(df_no_opa_owner) # Add a Series and convert to DataFrame
df_no_opa_resized = df_no_opa_resized.append(df_no_opa_vfx_1, ignore_index=True)
df_no_opa_resized = df_no_opa_resized.append(df_no_opa_vfx_2, ignore_index=True)
df_no_opa_resized = df_no_opa_resized.append(df_no_opa_vfx_3, ignore_index=True)
df_no_opa_resized = df_no_opa_resized.append(df_no_opa_color, ignore_index=True)
df_no_opa_resized = df_no_opa_resized.append(df_no_opa_sound, ignore_index=True)
df_no_opa_resized = df_no_opa_resized.append(df_no_opa_hdr, ignore_index=True)

## OPA data in one DataFrame
df_opa_resized = pd.DataFrame(df_opa_owner) # Add a Series and convert to DataFrame
df_opa_resized = df_opa_resized.append(df_opa_vfx_1, ignore_index=True)
df_opa_resized = df_opa_resized.append(df_opa_vfx_2, ignore_index=True)
df_opa_resized = df_opa_resized.append(df_opa_vfx_3, ignore_index=True)
df_opa_resized = df_opa_resized.append(df_opa_color, ignore_index=True)
df_opa_resized = df_opa_resized.append(df_opa_sound, ignore_index=True)
df_opa_resized = df_opa_resized.append(df_opa_hdr, ignore_index=True)

df_comp = pd.DataFrame(df_no_opa_resized["startup"].rename("no_opa")) # Add a Series and convert to DataFrame
df_comp = df_comp.assign(opa=df_opa_resized["startup"].values)

print(df_comp.shape)
# Out:
# (130, 6)
# (130, 6)
# (130, 6)
# (130, 6)
# (130, 6)
# (130, 6)
# (130, 6)
# (130, 6)
# (130, 6)
# (130, 6)
# (130, 6)
# (130, 6)
# (130, 6)
# (130, 6)
# (910, 2)

# %%
print(df_no_opa_resized)
print(df_opa_resized)
print(df_comp)
# Out:
#       name         pod_scheduled           initialized      containers_ready  \
# 0    owner  2020-09-03T15:57:04Z  2020-09-03T15:57:06Z  2020-09-03T15:57:10Z
# 1    owner  2020-09-03T16:01:54Z  2020-09-03T16:01:56Z  2020-09-03T16:02:01Z
# 2    owner  2020-09-03T16:06:24Z  2020-09-03T16:06:27Z  2020-09-03T16:06:30Z
# 3    owner  2020-09-03T16:11:14Z  2020-09-03T16:11:16Z  2020-09-03T16:11:20Z
# 4    owner  2020-09-03T16:16:04Z  2020-09-03T16:16:06Z  2020-09-03T16:16:10Z
# ..     ...                   ...                   ...                   ...
# 905    hdr  2020-09-03T20:43:40Z  2020-09-03T20:43:43Z  2020-09-03T20:43:46Z
# 906    hdr  2020-09-03T20:48:12Z  2020-09-03T20:48:14Z  2020-09-03T20:48:17Z
# 907    hdr  2020-09-03T20:52:56Z  2020-09-03T20:52:58Z  2020-09-03T20:53:03Z
# 908    hdr  2020-09-03T20:57:26Z  2020-09-03T20:57:28Z  2020-09-03T20:57:31Z
# 909    hdr  2020-09-03T21:01:57Z  2020-09-03T21:01:59Z  2020-09-03T21:02:03Z
#
#                     ready  startup
# 0    2020-09-03T15:57:10Z        6
# 1    2020-09-03T16:02:01Z        7
# 2    2020-09-03T16:06:30Z        6
# 3    2020-09-03T16:11:20Z        6
# 4    2020-09-03T16:16:10Z        6
# ..                    ...      ...
# 905  2020-09-03T20:43:46Z        6
# 906  2020-09-03T20:48:17Z        5
# 907  2020-09-03T20:53:03Z        7
# 908  2020-09-03T20:57:31Z        5
# 909  2020-09-03T21:02:03Z        6
#
# [910 rows x 6 columns]
#       name         pod_scheduled           initialized      containers_ready  \
# 0    owner  2020-06-10T19:36:38Z  2020-06-10T19:36:41Z  2020-06-10T19:36:46Z
# 1    owner  2020-06-10T21:34:33Z  2020-06-10T21:34:35Z  2020-06-10T21:34:40Z
# 2    owner  2020-06-10T21:39:08Z  2020-06-10T21:39:10Z  2020-06-10T21:39:15Z
# 3    owner  2020-06-10T21:43:35Z  2020-06-10T21:43:37Z  2020-06-10T21:43:43Z
# 4    owner  2020-06-10T21:48:18Z  2020-06-10T21:48:21Z  2020-06-10T21:48:26Z
# ..     ...                   ...                   ...                   ...
# 905    hdr  2020-06-15T16:14:47Z  2020-06-15T16:14:50Z  2020-06-15T16:14:55Z
# 906    hdr  2020-06-15T16:16:37Z  2020-06-15T16:16:40Z  2020-06-15T16:16:45Z
# 907    hdr  2020-06-15T16:18:38Z  2020-06-15T16:18:41Z  2020-06-15T16:18:46Z
# 908    hdr  2020-06-15T16:20:28Z  2020-06-15T16:20:30Z  2020-06-15T16:20:36Z
# 909    hdr  2020-06-15T16:22:25Z  2020-06-15T16:22:28Z  2020-06-15T16:22:35Z
#
#                     ready  startup
# 0    2020-06-10T19:36:46Z        8
# 1    2020-06-10T21:34:40Z        7
# 2    2020-06-10T21:39:15Z        7
# 3    2020-06-10T21:43:43Z        8
# 4    2020-06-10T21:48:26Z        8
# ..                    ...      ...
# 905  2020-06-15T16:14:55Z        8
# 906  2020-06-15T16:16:45Z        8
# 907  2020-06-15T16:18:46Z        8
# 908  2020-06-15T16:20:36Z        8
# 909  2020-06-15T16:22:35Z       10
#
# [910 rows x 6 columns]
#      no_opa  opa
# 0         6    8
# 1         7    7
# 2         6    7
# 3         6    8
# 4         6    8
# ..      ...  ...
# 905       6    8
# 906       5    8
# 907       7    8
# 908       5    8
# 909       6   10
#
# [910 rows x 2 columns]

# %% [markdown]
# # Plotting distributions
# ***

# %%
# Imports
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
from pylab import rcParams
from scipy.stats import f_oneway
from scipy.stats import ttest_ind

# %matplotlib inline
warnings.filterwarnings("ignore")
rcParams['figure.figsize'] = 20,10
rcParams['font.size'] = 30
sns.set()
np.random.seed(8)

# %%
df_comp.boxplot()

# %%
no_opa_col = pd.DataFrame(df_comp['no_opa'].rename("startup"))
no_opa_col['name'] = 'no_opa'
print(no_opa_col)

opa_col = pd.DataFrame(df_comp['opa'].rename("startup"))
opa_col['name'] = 'opa'
opa_col.drop(opa_col.index[len(opa_col)-1])
print(opa_col)

full_col = no_opa_col.append(opa_col, ignore_index=True)
print(full_col)

full_col.loc[full_col['name'] == "opa"]['startup']
# Out:
#      startup    name
# 0          6  no_opa
# 1          7  no_opa
# 2          6  no_opa
# 3          6  no_opa
# 4          6  no_opa
# ..       ...     ...
# 905        6  no_opa
# 906        5  no_opa
# 907        7  no_opa
# 908        5  no_opa
# 909        6  no_opa
#
# [910 rows x 2 columns]
#      startup name
# 0          8  opa
# 1          7  opa
# 2          7  opa
# 3          8  opa
# 4          8  opa
# ..       ...  ...
# 905        8  opa
# 906        8  opa
# 907        8  opa
# 908        8  opa
# 909       10  opa
#
# [910 rows x 2 columns]
#       startup    name
# 0           6  no_opa
# 1           7  no_opa
# 2           6  no_opa
# 3           6  no_opa
# 4           6  no_opa
# ...       ...     ...
# 1815        8     opa
# 1816        8     opa
# 1817        8     opa
# 1818        8     opa
# 1819       10     opa
#
# [1820 rows x 2 columns]
# 910      8
# 911      7
# 912      7
# 913      8
# 914      8
#         ..
# 1815     8
# 1816     8
# 1817     8
# 1818     8
# 1819    10
# Name: startup, Length: 910, dtype: int64

# %%
plt.figure()

params = {'legend.fontsize': 20,
          'legend.handlelength': 2}
plt.rcParams.update(params)

plt.rcParams.update({'font.size': 20})
sns.set_style("whitegrid")

ax = sns.countplot(x="startup", hue="name", data=full_col)
plt.ylabel("Number of observations", fontsize=20)
plt.xlabel("Startup time (s)", fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

# Define some hatches
hatches = ['-', '+', 'x', '\\', '*', 'o']

# Loop over the bars
for i,bar in enumerate(ax.patches):
    # Set a different hatch for each bar
    print(bar)
    if i <= 4:
        bar.set_hatch(hatches[3])

leg = ax.legend()

#plt.axvline(np.mean(full_col.loc[full_col['name'] == "opa"]['startup']), color="blue", linestyle="dashed", linewidth=5)
#plt.axvline(np.mean(full_col.loc[full_col['name'] == "no_opa"]['startup']), color="orange", linestyle="dotted", linewidth=5)

plt.show()
# Out:
# Rectangle(xy=(-0.4, 0), width=0.4, height=21, angle=0)
# Rectangle(xy=(0.6, 0), width=0.4, height=288, angle=0)
# Rectangle(xy=(1.6, 0), width=0.4, height=367, angle=0)
# Rectangle(xy=(2.6, 0), width=0.4, height=208, angle=0)
# Rectangle(xy=(3.6, 0), width=0.4, height=24, angle=0)
# Rectangle(xy=(4.6, 0), width=0.4, height=1, angle=0)
# Rectangle(xy=(5.6, 0), width=0.4, height=nan, angle=0)
# Rectangle(xy=(6.6, 0), width=0.4, height=1, angle=0)
# Rectangle(xy=(7.6, 0), width=0.4, height=nan, angle=0)
# Rectangle(xy=(8.6, 0), width=0.4, height=nan, angle=0)
# Rectangle(xy=(-2.77556e-17, 0), width=0.4, height=nan, angle=0)
# Rectangle(xy=(1, 0), width=0.4, height=2, angle=0)
# Rectangle(xy=(2, 0), width=0.4, height=63, angle=0)
# Rectangle(xy=(3, 0), width=0.4, height=269, angle=0)
# Rectangle(xy=(4, 0), width=0.4, height=358, angle=0)
# Rectangle(xy=(5, 0), width=0.4, height=167, angle=0)
# Rectangle(xy=(6, 0), width=0.4, height=44, angle=0)
# Rectangle(xy=(7, 0), width=0.4, height=5, angle=0)
# Rectangle(xy=(8, 0), width=0.4, height=1, angle=0)
# Rectangle(xy=(9, 0), width=0.4, height=1, angle=0)

# %%
# Countplots
fig, ax = plt.subplots(1,2)
sns.countplot(df_no_opa['startup'], ax=ax[0])
sns.countplot(df_opa['startup'], ax=ax[1])
fig.show()

# %%
# Plot the distribution of a DataFrame
def plot_distribution(inp, inp_color):
    plt.figure()
    ax = sns.distplot(inp, color=inp_color, bins=np.arange(inp.min(), inp.max() + 1), kde_kws={'bw':1}, hist_kws={'linewidth':0.1})
    plt.axvline(np.mean(inp), color=inp_color, linestyle="dashed", linewidth=5)
    _, max_ = plt.ylim()
    plt.text(
        inp.mean() + inp.mean() / 10,
        max_ - max_ / 10,
        "Mean: {:.2f}".format(inp.mean()),
    )
    return plt.figure

# %%
# Plotting the distribution of startup times with/without OPA
plot_distribution(df_no_opa["startup"], 'blue')
plot_distribution(df_opa["startup"], 'orange')
# Out:
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
# Plot the distribution of two DataFrames
def plot_distribution_2(inp1, inp2, title='Default title', inp_color1='blue', inp_color2='orange'):
    plt.figure()
    ax1 = sns.distplot(inp1, color=inp_color1, bins=np.arange(inp1.min(), inp1.max() + 1), kde_kws={'bw':1}, hist_kws={'linewidth':0.1})
    ax2 = sns.distplot(inp2, color=inp_color2, bins=np.arange(inp2.min(), inp2.max() + 1), kde_kws={'bw':1}, hist_kws={'linewidth':0.1})
    plt.axvline(np.mean(inp1), color=inp_color1, linestyle="dashed", linewidth=5)
    plt.axvline(np.mean(inp2), color=inp_color2, linestyle="dashed", linewidth=5)
    ax1.set_title(title, fontsize=16)
    return plt.figure

# %%
# Distribution of NO OPA vs OPA
plot_distribution_2(df_no_opa['startup'], df_opa['startup'])
# Out:
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
# Distribution of NO OPA vs OPA
plot_distribution_2(df_no_opa['startup'], df_opa['startup'])
# Out:
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
# Plot distribution for all pods
for no_opa_idx, df_no_opa_spe in enumerate(dfs_no_opa_pods):
    for opa_idx, df_opa_spe in enumerate(dfs_opa_pods):
        if no_opa_idx == opa_idx:           
            plot_distribution_2(df_no_opa_spe['startup'], df_opa_spe['startup'], df_opa_spe.iat[0,0])

# %% [markdown]
# # General statistics
# ***

# %%
print("OPA vs NO OPA")
print("Means       {}     {}".format(df_opa_resized["startup"].mean(), df_no_opa_resized["startup"].mean()))
print("Difference:          {}".format(df_opa_resized["startup"].mean() - df_no_opa_resized["startup"].mean()))
print("Std         {}     {}".format(df_opa_resized["startup"].std(), df_no_opa_resized["startup"].std()))
print("Difference:          {}".format(df_opa_resized["startup"].std() - df_no_opa_resized["startup"].std()))
print("\n")


for no_opa_idx, df_no_opa_spe in enumerate(dfs_no_opa_pods):
    for opa_idx, df_opa_spe in enumerate(dfs_opa_pods):
        if no_opa_idx == opa_idx:
            print(df_no_opa_spe.iat[0,0])
            print("Means       {}     {}".format(df_opa_spe["startup"].mean(), df_no_opa_spe["startup"].mean()))
            print("Difference:          {}".format(df_opa_spe["startup"].mean() - df_no_opa_spe["startup"].mean()))
            print("Std         {}     {}".format(df_opa_spe["startup"].std(), df_no_opa_spe["startup"].std()))
            print("Difference:          {}".format(df_opa_spe["startup"].std() - df_no_opa_spe["startup"].std()))
            print("\n")
# Out:
# OPA vs NO OPA
# Means       7.867032967032967     5.927472527472528
# Difference:          1.9395604395604389
# Std         1.0292269034153545     0.8808019565731993
# Difference:          0.14842494684215524
#
#
# owner
# Means       7.476923076923077     6.123076923076923
# Difference:          1.3538461538461544
# Std         1.0283982021833882     0.8166426316543978
# Difference:          0.2117555705289904
#
#
# vfx-1
# Means       8.161538461538461     5.884615384615385
# Difference:          2.276923076923076
# Std         1.0100567652621701     0.7638602025657604
# Difference:          0.24619656269640977
#
#
# vfx-2
# Means       8.238461538461538     5.569230769230769
# Difference:          2.6692307692307686
# Std         1.0624226093390632     0.735990199825863
# Difference:          0.3264324095132002
#
#
# vfx-3
# Means       8.423076923076923     5.423076923076923
# Difference:          3.0
# Std         0.9872472465496759     0.786172995296261
# Difference:          0.20107425125341494
#
#
# color
# Means       7.323076923076923     5.769230769230769
# Difference:          1.5538461538461537
# Std         0.8555825307386703     0.7317650058947318
# Difference:          0.12381752484393849
#
#
# sound
# Means       7.8307692307692305     6.3307692307692305
# Difference:          1.5
# Std         0.8990818877646132     1.0221459530974586
# Difference:          -0.12306406533284542
#
#
# hdr
# Means       7.615384615384615     6.392307692307693
# Difference:          1.2230769230769223
# Std         0.8295381678105607     0.8020917793002181
# Difference:          0.027446388510342534

# %% [markdown]
# # T-Tests
# ***

# %%
# t test
def t_test(arr_1, arr_2, alpha, sample_size):
    stat, p = ttest_ind(arr_1, arr_2)
    print('t-statistic=%.3f, p=%.3f' % (stat, p))
    if p > alpha:
        print('Same distributions (fail to reject H0)')
    else:
        print('Different distributions (reject H0)')

# %%
alpha = 0.05

print('NO OPA vs OPA')
t_test(df_opa_resized["startup"], df_no_opa_resized["startup"], alpha, len(df_no_opa_resized.index))
print('\n')

for no_opa_idx, df_no_opa_spe in enumerate(dfs_no_opa_pods):
    for opa_idx, df_opa_spe in enumerate(dfs_opa_pods):
        if no_opa_idx == opa_idx:
            print(df_no_opa_spe.iat[0,0])
            t_test(df_opa_spe["startup"], df_no_opa_spe["startup"], alpha, len(df_no_opa.index))
            print('\n')
# Out:
# NO OPA vs OPA
# t-statistic=43.191, p=0.000
# Different distributions (reject H0)
#
#
# owner
# t-statistic=11.755, p=0.000
# Different distributions (reject H0)
#
#
# vfx-1
# t-statistic=20.500, p=0.000
# Different distributions (reject H0)
#
#
# vfx-2
# t-statistic=23.547, p=0.000
# Different distributions (reject H0)
#
#
# vfx-3
# t-statistic=27.103, p=0.000
# Different distributions (reject H0)
#
#
# color
# t-statistic=15.736, p=0.000
# Different distributions (reject H0)
#
#
# sound
# t-statistic=12.563, p=0.000
# Different distributions (reject H0)
#
#
# hdr
# t-statistic=12.085, p=0.000
# Different distributions (reject H0)

# %% [markdown]
# # Effect sizes
# ***

# %%
import math

# function to calculate Cohen's d for independent samples
def cohend(number_of_observations_1, number_of_observations_2, standard_deviation_1, standard_deviation_2, mean_1, mean_2):
    # calculate the pooled standard deviation
    s = math.sqrt(((number_of_observations_1 - 1) * standard_deviation_1 + (number_of_observations_2 - 1) * standard_deviation_2) / (number_of_observations_1 + number_of_observations_2 - 2))
    # calculate the effect size
    return (mean_1 - mean_2) / s


print("NO OPA vs OPA")
print("Cohen's d {:.3f}".format(cohend(len(df_opa_resized.index), len(df_no_opa_resized.index), df_opa_resized["startup"].std(), df_no_opa_resized["startup"].std(), df_opa_resized["startup"].mean(), df_no_opa_resized["startup"].mean())))
print("\n")

for no_opa_idx, df_no_opa_spe in enumerate(dfs_no_opa_pods):
    for opa_idx, df_opa_spe in enumerate(dfs_opa_pods):
        if no_opa_idx == opa_idx:
            print(df_no_opa_spe.iat[0,0])
            print("Cohen's d {:.3f}".format(cohend(len(df_opa_spe.index), len(df_no_opa_spe.index), df_opa_spe["startup"].std(), df_no_opa_spe["startup"].std(), df_opa_spe["startup"].mean(), df_no_opa_spe["startup"].mean())))
            print("\n")
# Out:
# NO OPA vs OPA
# Cohen's d 1.985
#
#
# owner
# Cohen's d 1.410
#
#
# vfx-1
# Cohen's d 2.418
#
#
# vfx-2
# Cohen's d 2.815
#
#
# vfx-3
# Cohen's d 3.186
#
#
# color
# Cohen's d 1.744
#
#
# sound
# Cohen's d 1.530
#
#
# hdr
# Cohen's d 1.354

# %% [markdown]
# # Power analysis
# ***

# %%
# estimate sample size via power analysis
from statsmodels.stats.power import TTestIndPower

# Get sample size
def power_analysis(effect_size, alpha=0.05, power=0.95):
    analysis = TTestIndPower()
    sample_size = analysis.solve_power(effect_size, power=power, nobs1=None, ratio=1.0, alpha=alpha)
    return sample_size

# Get power
def power_analysis_2(sample_size, effect_size, alpha=0.05):
    analysis = TTestIndPower()
    power = analysis.solve_power(effect_size=effect_size, nobs1=sample_size, ratio=1.0, alpha=alpha)
    return power

# %%
# Required number of observations according to effect sizes and sample sizes
effect_sizes = np.array([0.2, 0.5, 0.6, 0.8, 1])
sample_sizes = np.array(range(5, 150))
# calculate power curves from multiple power analyses
analysis = TTestIndPower()
analysis.plot_power(dep_var='nobs', nobs=sample_sizes, effect_size=effect_sizes)
plt.show()

# %%
# Sample size from power analysis
print("NO OPA vs OPA")
print("Effect size: {:f}".format(cohend(len(df_opa_resized.index), len(df_no_opa_resized.index), df_opa_resized["startup"].std(), df_no_opa_resized["startup"].std(), df_opa_resized["startup"].mean(), df_no_opa_resized["startup"].mean())))
print("Effective sample size: {:f}".format(len(df_opa_resized.index)))
print("Required sample size: {:f}".format(power_analysis(cohend(len(df_opa_resized.index), len(df_no_opa_resized.index), df_opa_resized["startup"].std(), df_no_opa_resized["startup"].std(), df_opa_resized["startup"].mean(), df_no_opa_resized["startup"].mean()))))
print("\n")

for no_opa_idx, df_no_opa_spe in enumerate(dfs_no_opa_pods):
    for opa_idx, df_opa_spe in enumerate(dfs_opa_pods):
        if no_opa_idx == opa_idx:
            print(df_no_opa_spe.iat[0,0])
            print("Effect size: {:f}".format(cohend(len(df_opa_spe.index), len(df_no_opa_spe.index), df_opa_spe["startup"].std(), df_no_opa_spe["startup"].std(), df_opa_spe["startup"].mean(), df_no_opa_spe["startup"].mean())))
            print("Effective sample size: {:f}".format(len(df_opa_spe.index)))
            print("Required sample size: {:f}".format(power_analysis(cohend(len(df_opa_spe.index), len(df_no_opa_spe.index), df_opa_spe["startup"].std(), df_no_opa_spe["startup"].std(), df_opa_spe["startup"].mean(), df_no_opa_spe["startup"].mean()))))
            print("\n")
# Out:
# NO OPA vs OPA
# Effect size: 1.984716
# Effective sample size: 910.000000
# Required sample size: 7.707283
#
#
# owner
# Effect size: 1.409553
# Effective sample size: 130.000000
# Required sample size: 14.118688
#
#
# vfx-1
# Effect size: 2.417668
# Effective sample size: 130.000000
# Required sample size: 5.619090
#
#
# vfx-2
# Effect size: 2.814858
# Effective sample size: 130.000000
# Required sample size: 4.513262
#
#
# vfx-3
# Effect size: 3.185887
# Effective sample size: 130.000000
# Required sample size: 3.848674
#
#
# color
# Effect size: 1.744163
# Effective sample size: 130.000000
# Required sample size: 9.620570
#
#
# sound
# Effect size: 1.530442
# Effective sample size: 130.000000
# Required sample size: 12.147264
#
#
# hdr
# Effect size: 1.354122
# Effective sample size: 130.000000
# Required sample size: 15.205669

# %%
# Power from power analysis
print("NO OPA vs OPA")
print("Effect size: {:f}".format(cohend(len(df_opa_resized.index), len(df_no_opa_resized.index), df_opa_resized["startup"].std(), df_no_opa_resized["startup"].std(), df_opa_resized["startup"].mean(), df_no_opa_resized["startup"].mean())))
print("Sample size: {:f}".format(len(df_opa_resized.index)))
print("Power: {:f}".format(power_analysis_2(len(df_opa_resized.index), cohend(len(df_opa_resized.index), len(df_no_opa_resized.index), df_opa_resized["startup"].std(), df_no_opa_resized["startup"].std(), df_opa_resized["startup"].mean(), df_no_opa_resized["startup"].mean()))))
print("\n")

for no_opa_idx, df_no_opa_spe in enumerate(dfs_no_opa_pods):
    for opa_idx, df_opa_spe in enumerate(dfs_opa_pods):
        if no_opa_idx == opa_idx:
            print(df_no_opa_spe.iat[0,0])
            print("Effect size: {:f}".format(cohend(len(df_opa_spe.index), len(df_no_opa_spe.index), df_opa_spe["startup"].std(), df_no_opa_spe["startup"].std(), df_opa_spe["startup"].mean(), df_no_opa_spe["startup"].mean())))
            print("Effective sample size: {:f}".format(len(df_opa_spe.index)))
            print("Power: {:f}".format(power_analysis_2(len(df_opa_spe.index), cohend(len(df_opa_spe.index), len(df_no_opa_spe.index), df_opa_spe["startup"].std(), df_no_opa_spe["startup"].std(), df_opa_spe["startup"].mean(), df_no_opa_spe["startup"].mean()))))
            print("\n")
# Out:
# NO OPA vs OPA
# Effect size: 1.984716
# Sample size: 910.000000
# Power: 1.000000
#
#
# owner
# Effect size: 1.409553
# Effective sample size: 130.000000
# Power: 1.000000
#
#
# vfx-1
# Effect size: 2.417668
# Effective sample size: 130.000000
# Power: 1.000000
#
#
# vfx-2
# Effect size: 2.814858
# Effective sample size: 130.000000
# Power: 1.000000
#
#
# vfx-3
# Effect size: 3.185887
# Effective sample size: 130.000000
# Power: 1.000000
#
#
# color
# Effect size: 1.744163
# Effective sample size: 130.000000
# Power: 1.000000
#
#
# sound
# Effect size: 1.530442
# Effective sample size: 130.000000
# Power: 1.000000
#
#
# hdr
# Effect size: 1.354122
# Effective sample size: 130.000000
# Power: 1.000000

# %%
# Percentages
low_bound_percent = 0.2161301428817355 / 7.445859872611465 * 100
high_bound_percent = 1.1472463768115952 / 8.173913043478262 * 100

print(low_bound_percent, high_bound_percent)
# Out:
# 2.9026888308325467 14.035460992907813
