# %% [markdown]
# # Loading and visualizing data
# ***

# %%
import ast
import pandas as pd

# Add old measures or not
old_measures = True

no_opa_data = []
with open("movie-wfs-no-opa-request-time.dat", 'r') as f:
    for line in f:
        no_opa_data.append(ast.literal_eval(line))


opa_all_allow_data = []
with open("movie-wfs-opa-all-allow-request-time.dat", 'r') as f:
    for line in f:
        opa_all_allow_data.append(ast.literal_eval(line))

if old_measures:
    with open("movie-wfs-opa-all-allow-request-time-old.dat", 'r') as f:
        for line in f:
            opa_all_allow_data.append(ast.literal_eval(line))


opa_minimal_data = []
with open("movie-wfs-opa-minimal-request-time.dat", 'r') as f:
    for line in f:
        opa_minimal_data.append(ast.literal_eval(line))

if old_measures:
    with open("movie-wfs-opa-minimal-request-time-old.dat", 'r') as f:
        for line in f:
            opa_minimal_data.append(ast.literal_eval(line))


opa_bulked_up_100_data = []
with open("movie-wfs-opa-bulked-up-100-request-time.dat", 'r') as f:
    for line in f:
        opa_bulked_up_100_data.append(ast.literal_eval(line))


opa_bulked_up_1000_data = []
with open("movie-wfs-opa-bulked-up-1000-request-time.dat", 'r') as f:
    for line in f:
        opa_bulked_up_1000_data.append(ast.literal_eval(line))

if old_measures:
    with open("movie-wfs-opa-bulked-up-1000-request-time-old.dat", 'r') as f:
        for line in f:
            opa_bulked_up_1000_data.append(ast.literal_eval(line))

# %%
# Put data in DataFrames and convert relevant columns to float values

df_no_opa = pd.DataFrame(no_opa_data, columns=['src', 'dst', 'time_namelookup', 'time_connect', 'time_appconnect', 'time_pretransfer', 'time_redirect', 'time_starttransfer', 'time_total'])
df_opa_all_allow = pd.DataFrame(opa_all_allow_data, columns=['src', 'dst', 'time_namelookup', 'time_connect', 'time_appconnect', 'time_pretransfer', 'time_redirect', 'time_starttransfer', 'time_total'])
df_opa_minimal = pd.DataFrame(opa_minimal_data, columns=['src', 'dst', 'time_namelookup', 'time_connect', 'time_appconnect', 'time_pretransfer', 'time_redirect', 'time_starttransfer', 'time_total'])
df_opa_bulked_up_100 = pd.DataFrame(opa_bulked_up_100_data, columns=['src', 'dst', 'time_namelookup', 'time_connect', 'time_appconnect', 'time_pretransfer', 'time_redirect', 'time_starttransfer', 'time_total'])
df_opa_bulked_up_1000 = pd.DataFrame(opa_bulked_up_1000_data, columns=['src', 'dst', 'time_namelookup', 'time_connect', 'time_appconnect', 'time_pretransfer', 'time_redirect', 'time_starttransfer', 'time_total'])

float_cols = ['time_namelookup', 'time_connect', 'time_appconnect', 'time_pretransfer', 'time_redirect', 'time_starttransfer', 'time_total']

for col in float_cols:
    df_no_opa[col] = df_no_opa[col].astype(float)
    df_opa_all_allow[col] = df_opa_all_allow[col].astype(float)
    df_opa_minimal[col] = df_opa_minimal[col].astype(float)
    df_opa_bulked_up_100[col] = df_opa_bulked_up_100[col].astype(float)
    df_opa_bulked_up_1000[col] = df_opa_bulked_up_1000[col].astype(float)

# %%
df_no_opa.describe()
# Out:
#        time_namelookup  time_connect  time_appconnect  time_pretransfer  \
# count     21738.000000  21738.000000          21738.0      21738.000000
# mean          0.000035      0.000183              0.0          0.000236
# std           0.000063      0.000116              0.0          0.000154
# min           0.000022      0.000107              0.0          0.000141
# 25%           0.000027      0.000143              0.0          0.000185
# 50%           0.000030      0.000158              0.0          0.000203
# 75%           0.000035      0.000183              0.0          0.000230
# max           0.006075      0.006232              0.0          0.006279
#
#        time_redirect  time_starttransfer    time_total
# count        21738.0        21738.000000  21738.000000
# mean             0.0            0.028727      0.028809
# std              0.0            0.023935      0.023941
# min              0.0            0.003622      0.003742
# ...

# %%
df_opa_all_allow.describe()
# Out:
#        time_namelookup  time_connect  time_appconnect  time_pretransfer  \
# count      6393.000000   6393.000000           6393.0       6393.000000
# mean          0.000035      0.000186              0.0          0.000240
# std           0.000055      0.000140              0.0          0.000185
# min           0.000021      0.000097              0.0          0.000129
# 25%           0.000027      0.000143              0.0          0.000184
# 50%           0.000030      0.000159              0.0          0.000203
# 75%           0.000035      0.000185              0.0          0.000232
# max           0.003066      0.004344              0.0          0.004632
#
#        time_redirect  time_starttransfer   time_total
# count         6393.0         6393.000000  6393.000000
# mean             0.0            0.028986     0.029072
# std              0.0            0.024776     0.024775
# min              0.0            0.005334     0.005642
# ...

# %%
df_opa_minimal.describe()
# Out:
#        time_namelookup  time_connect  time_appconnect  time_pretransfer  \
# count      5897.000000   5897.000000           5897.0       5897.000000
# mean          0.000036      0.000184              0.0          0.000237
# std           0.000035      0.000105              0.0          0.000145
# min           0.000022      0.000108              0.0          0.000147
# 25%           0.000026      0.000141              0.0          0.000183
# 50%           0.000030      0.000156              0.0          0.000201
# 75%           0.000036      0.000181              0.0          0.000228
# max           0.001565      0.002485              0.0          0.003381
#
#        time_redirect  time_starttransfer   time_total
# count         5897.0         5897.000000  5897.000000
# mean             0.0            0.032118     0.032155
# std              0.0            0.024722     0.024729
# min              0.0            0.003089     0.003111
# ...

# %%
df_opa_bulked_up_100.describe()
# Out:
#        time_namelookup  time_connect  time_appconnect  time_pretransfer  \
# count      1834.000000   1834.000000           1834.0       1834.000000
# mean          0.000033      0.000169              0.0          0.000219
# std           0.000037      0.000076              0.0          0.000122
# min           0.000024      0.000114              0.0          0.000150
# 25%           0.000027      0.000143              0.0          0.000185
# 50%           0.000029      0.000155              0.0          0.000198
# 75%           0.000034      0.000175              0.0          0.000220
# max           0.001345      0.001586              0.0          0.002808
#
#        time_redirect  time_starttransfer   time_total
# count         1834.0         1834.000000  1834.000000
# mean             0.0            0.029946     0.029980
# std              0.0            0.025236     0.025238
# min              0.0            0.003595     0.003612
# ...

# %%
df_opa_bulked_up_1000.describe()
# Out:
#        time_namelookup  time_connect  time_appconnect  time_pretransfer  \
# count      6531.000000   6531.000000           6531.0       6531.000000
# mean          0.000033      0.000167              0.0          0.000219
# std           0.000031      0.000081              0.0          0.000126
# min           0.000022      0.000113              0.0          0.000147
# 25%           0.000026      0.000141              0.0          0.000183
# 50%           0.000029      0.000153              0.0          0.000197
# 75%           0.000034      0.000174              0.0          0.000221
# max           0.001223      0.002359              0.0          0.004300
#
#        time_redirect  time_starttransfer   time_total
# count         6531.0         6531.000000  6531.000000
# mean             0.0            0.033753     0.033788
# std              0.0            0.024411     0.024411
# min              0.0            0.006444     0.006466
# ...

# %% [markdown]
# # Filtering DataFrames by communications
# ***

# %%
# Communication couples that are authorized
comm_couples = [("owner", "vfx-1"), ("vfx-1", "vfx-2"), ("vfx-1", "vfx-3"), ("vfx-2", "color"), ("vfx-3", "sound"), ("color", "hdr"), ("hdr", "owner"), ("sound", "owner")]

# Dfs no opa
df_no_opa_owner_vfx1 = df_no_opa[(df_no_opa.src == "owner") & (df_no_opa.dst == "vfx-1")]
df_no_opa_vfx1_vfx2 = df_no_opa[(df_no_opa.src == "vfx-1") & (df_no_opa.dst == "vfx-2")]
df_no_opa_vfx1_vfx3 = df_no_opa[(df_no_opa.src == "vfx-1") & (df_no_opa.dst == "vfx-3")]
df_no_opa_vfx2_color = df_no_opa[(df_no_opa.src == "vfx-2") & (df_no_opa.dst == "color")]
df_no_opa_vfx3_sound = df_no_opa[(df_no_opa.src == "vfx-3") & (df_no_opa.dst == "sound")]
df_no_opa_color_hdr = df_no_opa[(df_no_opa.src == "color") & (df_no_opa.dst == "hdr")]
df_no_opa_hdr_owner = df_no_opa[(df_no_opa.src == "hdr") & (df_no_opa.dst == "owner")]
df_no_opa_sound_owner = df_no_opa[(df_no_opa.src == "sound") & (df_no_opa.dst == "owner")]

dfs_no_opa = [df_no_opa_owner_vfx1, df_no_opa_vfx1_vfx2, df_no_opa_vfx1_vfx3, df_no_opa_vfx2_color, df_no_opa_vfx3_sound, df_no_opa_color_hdr, df_no_opa_hdr_owner, df_no_opa_sound_owner]

# Dfs opa all allow
df_opa_all_allow_owner_vfx1 = df_opa_all_allow[(df_opa_all_allow.src == "owner") & (df_opa_all_allow.dst == "vfx-1")]
df_opa_all_allow_vfx1_vfx2 = df_opa_all_allow[(df_opa_all_allow.src == "vfx-1") & (df_opa_all_allow.dst == "vfx-2")]
df_opa_all_allow_vfx1_vfx3 = df_opa_all_allow[(df_opa_all_allow.src == "vfx-1") & (df_opa_all_allow.dst == "vfx-3")]
df_opa_all_allow_vfx2_color = df_opa_all_allow[(df_opa_all_allow.src == "vfx-2") & (df_opa_all_allow.dst == "color")]
df_opa_all_allow_vfx3_sound = df_opa_all_allow[(df_opa_all_allow.src == "vfx-3") & (df_opa_all_allow.dst == "sound")]
df_opa_all_allow_color_hdr = df_opa_all_allow[(df_opa_all_allow.src == "color") & (df_opa_all_allow.dst == "hdr")]
df_opa_all_allow_hdr_owner = df_opa_all_allow[(df_opa_all_allow.src == "hdr") & (df_opa_all_allow.dst == "owner")]
df_opa_all_allow_sound_owner = df_opa_all_allow[(df_opa_all_allow.src == "sound") & (df_opa_all_allow.dst == "owner")]

dfs_opa_all_allow = [df_opa_all_allow_owner_vfx1, df_opa_all_allow_vfx1_vfx2, df_opa_all_allow_vfx1_vfx3, df_opa_all_allow_vfx2_color, df_opa_all_allow_vfx3_sound, df_opa_all_allow_color_hdr, df_opa_all_allow_hdr_owner, df_opa_all_allow_sound_owner]


# Dfs opa minimal
df_opa_minimal_owner_vfx1 = df_opa_minimal[(df_opa_minimal.src == "owner") & (df_opa_minimal.dst == "vfx-1")]
df_opa_minimal_vfx1_vfx2 = df_opa_minimal[(df_opa_minimal.src == "vfx-1") & (df_opa_minimal.dst == "vfx-2")]
df_opa_minimal_vfx1_vfx3 = df_opa_minimal[(df_opa_minimal.src == "vfx-1") & (df_opa_minimal.dst == "vfx-3")]
df_opa_minimal_vfx2_color = df_opa_minimal[(df_opa_minimal.src == "vfx-2") & (df_opa_minimal.dst == "color")]
df_opa_minimal_vfx3_sound = df_opa_minimal[(df_opa_minimal.src == "vfx-3") & (df_opa_minimal.dst == "sound")]
df_opa_minimal_color_hdr = df_opa_minimal[(df_opa_minimal.src == "color") & (df_opa_minimal.dst == "hdr")]
df_opa_minimal_hdr_owner = df_opa_minimal[(df_opa_minimal.src == "hdr") & (df_opa_minimal.dst == "owner")]
df_opa_minimal_sound_owner = df_opa_minimal[(df_opa_minimal.src == "sound") & (df_opa_minimal.dst == "owner")]

dfs_opa_minimal = [df_opa_minimal_owner_vfx1, df_opa_minimal_vfx1_vfx2, df_opa_minimal_vfx1_vfx3, df_opa_minimal_vfx2_color, df_opa_minimal_vfx3_sound, df_opa_minimal_color_hdr, df_opa_minimal_hdr_owner, df_opa_minimal_sound_owner]


# Dfs opa bulked up 100
df_opa_bulked_up_100_owner_vfx1 = df_opa_bulked_up_100[(df_opa_bulked_up_100.src == "owner") & (df_opa_bulked_up_100.dst == "vfx-1")]
df_opa_bulked_up_100_vfx1_vfx2 = df_opa_bulked_up_100[(df_opa_bulked_up_100.src == "vfx-1") & (df_opa_bulked_up_100.dst == "vfx-2")]
df_opa_bulked_up_100_vfx1_vfx3 = df_opa_bulked_up_100[(df_opa_bulked_up_100.src == "vfx-1") & (df_opa_bulked_up_100.dst == "vfx-3")]
df_opa_bulked_up_100_vfx2_color = df_opa_bulked_up_100[(df_opa_bulked_up_100.src == "vfx-2") & (df_opa_bulked_up_100.dst == "color")]
df_opa_bulked_up_100_vfx3_sound = df_opa_bulked_up_100[(df_opa_bulked_up_100.src == "vfx-3") & (df_opa_bulked_up_100.dst == "sound")]
df_opa_bulked_up_100_color_hdr = df_opa_bulked_up_100[(df_opa_bulked_up_100.src == "color") & (df_opa_bulked_up_100.dst == "hdr")]
df_opa_bulked_up_100_hdr_owner = df_opa_bulked_up_100[(df_opa_bulked_up_100.src == "hdr") & (df_opa_bulked_up_100.dst == "owner")]
df_opa_bulked_up_100_sound_owner = df_opa_bulked_up_100[(df_opa_bulked_up_100.src == "sound") & (df_opa_bulked_up_100.dst == "owner")]

dfs_opa_bulked_up_100 = [df_opa_bulked_up_100_owner_vfx1, df_opa_bulked_up_100_vfx1_vfx2, df_opa_bulked_up_100_vfx1_vfx3, df_opa_bulked_up_100_vfx2_color, df_opa_bulked_up_100_vfx3_sound, df_opa_bulked_up_100_color_hdr, df_opa_bulked_up_100_hdr_owner, df_opa_bulked_up_100_sound_owner]


# Dfs opa bulked up 1000
df_opa_bulked_up_1000_owner_vfx1 = df_opa_bulked_up_1000[(df_opa_bulked_up_1000.src == "owner") & (df_opa_bulked_up_1000.dst == "vfx-1")]
df_opa_bulked_up_1000_vfx1_vfx2 = df_opa_bulked_up_1000[(df_opa_bulked_up_1000.src == "vfx-1") & (df_opa_bulked_up_1000.dst == "vfx-2")]
df_opa_bulked_up_1000_vfx1_vfx3 = df_opa_bulked_up_1000[(df_opa_bulked_up_1000.src == "vfx-1") & (df_opa_bulked_up_1000.dst == "vfx-3")]
df_opa_bulked_up_1000_vfx2_color = df_opa_bulked_up_1000[(df_opa_bulked_up_1000.src == "vfx-2") & (df_opa_bulked_up_1000.dst == "color")]
df_opa_bulked_up_1000_vfx3_sound = df_opa_bulked_up_1000[(df_opa_bulked_up_1000.src == "vfx-3") & (df_opa_bulked_up_1000.dst == "sound")]
df_opa_bulked_up_1000_color_hdr = df_opa_bulked_up_1000[(df_opa_bulked_up_1000.src == "color") & (df_opa_bulked_up_1000.dst == "hdr")]
df_opa_bulked_up_1000_hdr_owner = df_opa_bulked_up_1000[(df_opa_bulked_up_1000.src == "hdr") & (df_opa_bulked_up_1000.dst == "owner")]
df_opa_bulked_up_1000_sound_owner = df_opa_bulked_up_1000[(df_opa_bulked_up_1000.src == "sound") & (df_opa_bulked_up_1000.dst == "owner")]

dfs_opa_bulked_up_1000 = [df_opa_bulked_up_1000_owner_vfx1, df_opa_bulked_up_1000_vfx1_vfx2, df_opa_bulked_up_1000_vfx1_vfx3, df_opa_bulked_up_1000_vfx2_color, df_opa_bulked_up_1000_vfx3_sound, df_opa_bulked_up_1000_color_hdr, df_opa_bulked_up_1000_hdr_owner, df_opa_bulked_up_1000_sound_owner]


print("dfs_no_opa")
for df in dfs_no_opa:
    print(df.iat[0,0], df.iat[0,1])
    print(df.shape)
print("")

print("dfs_opa_all_allow")
for df in dfs_opa_all_allow:
    print(df.iat[0,0], df.iat[0,1])
    print(df.shape)
print("")

print("dfs_opa_minimal")
for df in dfs_opa_minimal:
    print(df.iat[0,0], df.iat[0,1])
    print(df.shape)
print("")

print("dfs_opa_bulked_up_100")
for df in dfs_opa_bulked_up_100:
    print(df.iat[0,0], df.iat[0,1])
    print(df.shape)
print("")

print("dfs_opa_bulked_up_1000")
for df in dfs_opa_bulked_up_1000:
    print(df.iat[0,0], df.iat[0,1])
    print(df.shape)
print("")
# Out:
# dfs_no_opa
# owner vfx-1
# (551, 9)
# vfx-1 vfx-2
# (551, 9)
# vfx-1 vfx-3
# (551, 9)
# vfx-2 color
# (420, 9)
# vfx-3 sound
# (548, 9)
# color hdr
# (527, 9)
# hdr owner
# (510, 9)
# sound owner
# (694, 9)
#
# dfs_opa_all_allow
# owner vfx-1
# (117, 9)
# vfx-1 vfx-2
# (223, 9)
# vfx-1 vfx-3
# (223, 9)
# vfx-2 color
# (223, 9)
# vfx-3 sound
# (176, 9)
# color hdr
# (113, 9)
# hdr owner
# (112, 9)
# sound owner
# (66, 9)
#
# dfs_opa_minimal
# owner vfx-1
# (97, 9)
# vfx-1 vfx-2
# (97, 9)
# vfx-1 vfx-3
# (97, 9)
# vfx-2 color
# (97, 9)
# vfx-3 sound
# (97, 9)
# color hdr
# (250, 9)
# hdr owner
# (249, 9)
# sound owner
# (250, 9)
#
# dfs_opa_bulked_up_100
# owner vfx-1
# (44, 9)
# vfx-1 vfx-2
# (44, 9)
# vfx-1 vfx-3
# (44, 9)
# vfx-2 color
# (44, 9)
# vfx-3 sound
# (44, 9)
# color hdr
# (44, 9)
# hdr owner
# (43, 9)
# sound owner
# (43, 9)
#
# dfs_opa_bulked_up_1000
# owner vfx-1
# (135, 9)
# vfx-1 vfx-2
# (182, 9)
# vfx-1 vfx-3
# (182, 9)
# vfx-2 color
# (182, 9)
# vfx-3 sound
# ...

# %% [markdown]
# # Matching sample sizes across DataFrames
# ***

# %%
equal_sample_size = 40

# Adjust sample sizes for comparison

# Dfs no opa
df_no_opa_owner_vfx1 = df_no_opa_owner_vfx1.head(equal_sample_size)
df_no_opa_vfx1_vfx2 = df_no_opa_vfx1_vfx2.head(equal_sample_size)
df_no_opa_vfx1_vfx3 = df_no_opa_vfx1_vfx3.head(equal_sample_size)
df_no_opa_vfx2_color = df_no_opa_vfx2_color.head(equal_sample_size)
df_no_opa_vfx3_sound = df_no_opa_vfx3_sound.head(equal_sample_size)
df_no_opa_color_hdr = df_no_opa_color_hdr.head(equal_sample_size)
df_no_opa_hdr_owner = df_no_opa_hdr_owner.head(equal_sample_size)
df_no_opa_sound_owner = df_no_opa_sound_owner.head(equal_sample_size)

dfs_no_opa = [df_no_opa_owner_vfx1, df_no_opa_vfx1_vfx2, df_no_opa_vfx1_vfx3, df_no_opa_vfx2_color, df_no_opa_vfx3_sound, df_no_opa_color_hdr, df_no_opa_hdr_owner, df_no_opa_sound_owner]


# Dfs opa all allow
df_opa_all_allow_owner_vfx1 = df_opa_all_allow_owner_vfx1.head(equal_sample_size)
df_opa_all_allow_vfx1_vfx2 = df_opa_all_allow_vfx1_vfx2.head(equal_sample_size)
df_opa_all_allow_vfx1_vfx3 = df_opa_all_allow_vfx1_vfx3.head(equal_sample_size)
df_opa_all_allow_vfx2_color = df_opa_all_allow_vfx2_color.head(equal_sample_size)
df_opa_all_allow_vfx3_sound = df_opa_all_allow_vfx3_sound.head(equal_sample_size)
df_opa_all_allow_color_hdr = df_opa_all_allow_color_hdr.head(equal_sample_size)
df_opa_all_allow_hdr_owner = df_opa_all_allow_hdr_owner.head(equal_sample_size)
df_opa_all_allow_sound_owner = df_opa_all_allow_sound_owner.head(equal_sample_size)

dfs_opa_all_allow = [df_opa_all_allow_owner_vfx1, df_opa_all_allow_vfx1_vfx2, df_opa_all_allow_vfx1_vfx3, df_opa_all_allow_vfx2_color, df_opa_all_allow_vfx3_sound, df_opa_all_allow_color_hdr, df_opa_all_allow_hdr_owner, df_opa_all_allow_sound_owner]


# Dfs opa minimal
df_opa_minimal_owner_vfx1 = df_opa_minimal_owner_vfx1.head(equal_sample_size)
df_opa_minimal_vfx1_vfx2 = df_opa_minimal_vfx1_vfx2.head(equal_sample_size)
df_opa_minimal_vfx1_vfx3 = df_opa_minimal_vfx1_vfx3.head(equal_sample_size)
df_opa_minimal_vfx2_color = df_opa_minimal_vfx2_color.head(equal_sample_size)
df_opa_minimal_vfx3_sound = df_opa_minimal_vfx3_sound.head(equal_sample_size)
df_opa_minimal_color_hdr = df_opa_minimal_color_hdr.head(equal_sample_size)
df_opa_minimal_hdr_owner = df_opa_minimal_hdr_owner.head(equal_sample_size)
df_opa_minimal_sound_owner = df_opa_minimal_sound_owner.head(equal_sample_size)

dfs_opa_minimal = [df_opa_minimal_owner_vfx1, df_opa_minimal_vfx1_vfx2, df_opa_minimal_vfx1_vfx3, df_opa_minimal_vfx2_color, df_opa_minimal_vfx3_sound, df_opa_minimal_color_hdr, df_opa_minimal_hdr_owner, df_opa_minimal_sound_owner]


# Dfs opa bulked up 100
df_opa_bulked_up_100_owner_vfx1 = df_opa_bulked_up_100_owner_vfx1.head(equal_sample_size)
df_opa_bulked_up_100_vfx1_vfx2 = df_opa_bulked_up_100_vfx1_vfx2.head(equal_sample_size)
df_opa_bulked_up_100_vfx1_vfx3 = df_opa_bulked_up_100_vfx1_vfx3.head(equal_sample_size)
df_opa_bulked_up_100_vfx2_color = df_opa_bulked_up_100_vfx2_color.head(equal_sample_size)
df_opa_bulked_up_100_vfx3_sound = df_opa_bulked_up_100_vfx3_sound.head(equal_sample_size)
df_opa_bulked_up_100_color_hdr = df_opa_bulked_up_100_color_hdr.head(equal_sample_size)
df_opa_bulked_up_100_hdr_owner = df_opa_bulked_up_100_hdr_owner.head(equal_sample_size)
df_opa_bulked_up_100_sound_owner = df_opa_bulked_up_100_sound_owner.head(equal_sample_size)

dfs_opa_bulked_up_100 = [df_opa_bulked_up_100_owner_vfx1, df_opa_bulked_up_100_vfx1_vfx2, df_opa_bulked_up_100_vfx1_vfx3, df_opa_bulked_up_100_vfx2_color, df_opa_bulked_up_100_vfx3_sound, df_opa_bulked_up_100_color_hdr, df_opa_bulked_up_100_hdr_owner, df_opa_bulked_up_100_sound_owner]


# Dfs opa bulked up 1000
df_opa_bulked_up_1000_owner_vfx1 = df_opa_bulked_up_1000_owner_vfx1.head(equal_sample_size)
df_opa_bulked_up_1000_vfx1_vfx2 = df_opa_bulked_up_1000_vfx1_vfx2.head(equal_sample_size)
df_opa_bulked_up_1000_vfx1_vfx3 = df_opa_bulked_up_1000_vfx1_vfx3.head(equal_sample_size)
df_opa_bulked_up_1000_vfx2_color = df_opa_bulked_up_1000_vfx2_color.head(equal_sample_size)
df_opa_bulked_up_1000_vfx3_sound = df_opa_bulked_up_1000_vfx3_sound.head(equal_sample_size)
df_opa_bulked_up_1000_color_hdr = df_opa_bulked_up_1000_color_hdr.head(equal_sample_size)
df_opa_bulked_up_1000_hdr_owner = df_opa_bulked_up_1000_hdr_owner.head(equal_sample_size)
df_opa_bulked_up_1000_sound_owner = df_opa_bulked_up_1000_sound_owner.head(equal_sample_size)

dfs_opa_bulked_up_1000 = [df_opa_bulked_up_1000_owner_vfx1, df_opa_bulked_up_1000_vfx1_vfx2, df_opa_bulked_up_1000_vfx1_vfx3, df_opa_bulked_up_1000_vfx2_color, df_opa_bulked_up_1000_vfx3_sound, df_opa_bulked_up_1000_color_hdr, df_opa_bulked_up_1000_hdr_owner, df_opa_bulked_up_1000_sound_owner]


# Verify shapes of DataFrames
print("dfs_no_opa")
for df in dfs_no_opa:
    print(df.iat[0,0], df.iat[0,1])
    print(df.shape)
print("")

print("dfs_opa_all_allow")
for df in dfs_opa_all_allow:
    print(df.iat[0,0], df.iat[0,1])
    print(df.shape)
print("")

print("dfs_opa_minimal")
for df in dfs_opa_minimal:
    print(df.iat[0,0], df.iat[0,1])
    print(df.shape)
print("")

print("dfs_opa_bulked_up_100")
for df in dfs_opa_bulked_up_100:
    print(df.iat[0,0], df.iat[0,1])
    print(df.shape)
print("")

print("dfs_opa_bulked_up_1000")
for df in dfs_opa_bulked_up_1000:
    print(df.iat[0,0], df.iat[0,1])
    print(df.shape)
print("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-add287334e92> in <module>
#       9 df_no_opa_vfx2_color = df_no_opa_vfx2_color.head(equal_sample_size)
#      10 df_no_opa_vfx3_sound = df_no_opa_vfx3_sound.head(equal_sample_size)
# ---> 11 df_no_opa_color_hdr = d1400f_no_opa_color_hdr.head(equal_sample_size)
#      12 df_no_opa_hdr_owner = df_no_opa_hdr_owner.head(equal_sample_size)
#      13 df_no_opa_sound_owner = df_no_opa_sound_owner.head(equal_sample_size)
#
# NameError: name 'd1400f_no_opa_color_hdr' is not defined

# %% [markdown]
# # Plotting distributions
# ***

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
from pylab import rcParams
from scipy.stats import f_oneway
from scipy.stats import ttest_ind

# %matplotlib inline
warnings.filterwarnings("ignore")
rcParams['figure.figsize'] = 20,10
rcParams['font.size'] = 30
sns.set()
np.random.seed(8)

# %%
def plot_distribution(inp):
    plt.figure()
    ax = sns.distplot(inp)
    plt.axvline(np.mean(inp), color="k", linestyle="dashed", linewidth=5)
    _, max_ = plt.ylim()
    plt.text(
        inp.mean() + inp.mean() / 10,
        max_ - max_ / 10,
        "Mean: {:.2f}".format(inp.mean()),
    )
    return plt.figure

# %%
# Distplot with means comparing all policy deployments
# The two bumps in each distribution correspond respectively to intra/inter region communications
plt.figure()
ax1 = sns.distplot(df_no_opa["time_total"], color='blue')
ax2 = sns.distplot(df_opa_all_allow["time_total"], color='green')
ax3 = sns.distplot(df_opa_minimal["time_total"], color='yellow')
ax4 = sns.distplot(df_opa_bulked_up_100["time_total"], color='orange')
ax5 = sns.distplot(df_opa_bulked_up_1000["time_total"], color='red')
plt.axvline(np.mean(df_no_opa["time_total"]), color='blue', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_all_allow["time_total"]), color='green', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_minimal["time_total"]), color='yellow', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_100["time_total"]), color='orange', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000["time_total"]), color='red', linestyle='dashed', linewidth=5)

# %%
# Distplot with means of the no opa deployment, displaying all communications
plt.figure()
ax1 = sns.distplot(df_no_opa_owner_vfx1["time_total"], color='blue')
ax2 = sns.distplot(df_no_opa_vfx1_vfx2["time_total"], color='green')
ax3 = sns.distplot(df_no_opa_vfx1_vfx3["time_total"], color='yellow')
ax4 = sns.distplot(df_no_opa_vfx2_color["time_total"], color='orange')
ax5 = sns.distplot(df_no_opa_vfx3_sound["time_total"], color='red')
ax6 = sns.distplot(df_no_opa_color_hdr["time_total"], color='pink')
ax7 = sns.distplot(df_no_opa_hdr_owner["time_total"], color='purple')
ax8 = sns.distplot(df_no_opa_sound_owner["time_total"], color='grey')
plt.axvline(np.mean(df_no_opa_owner_vfx1["time_total"]), color='blue', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_no_opa_vfx1_vfx2["time_total"]), color='green', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_no_opa_vfx1_vfx3["time_total"]), color='yellow', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_no_opa_vfx2_color["time_total"]), color='orange', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_no_opa_vfx3_sound["time_total"]), color='red', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_no_opa_color_hdr["time_total"]), color='pink', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_no_opa_hdr_owner["time_total"]), color='purple', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_no_opa_sound_owner["time_total"]), color='grey', linestyle='dashed', linewidth=5)

# %%
# Distplot with means of the bulked up 1000 deployment, displaying all communications
plt.figure()
ax1 = sns.distplot(df_opa_bulked_up_1000_owner_vfx1["time_total"], color='blue')
ax2 = sns.distplot(df_opa_bulked_up_1000_vfx1_vfx2["time_total"], color='green')
ax3 = sns.distplot(df_opa_bulked_up_1000_vfx1_vfx3["time_total"], color='yellow')
ax4 = sns.distplot(df_opa_bulked_up_1000_vfx2_color["time_total"], color='orange')
ax5 = sns.distplot(df_opa_bulked_up_1000_vfx3_sound["time_total"], color='red')
ax6 = sns.distplot(df_opa_bulked_up_1000_color_hdr["time_total"], color='pink')
ax7 = sns.distplot(df_opa_bulked_up_1000_hdr_owner["time_total"], color='purple')
ax8 = sns.distplot(df_opa_bulked_up_1000_sound_owner["time_total"], color='grey')
plt.axvline(np.mean(df_opa_bulked_up_1000_owner_vfx1["time_total"]), color='blue', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx1_vfx2["time_total"]), color='green', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx1_vfx3["time_total"]), color='yellow', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx2_color["time_total"]), color='orange', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx3_sound["time_total"]), color='red', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_color_hdr["time_total"]), color='pink', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_hdr_owner["time_total"]), color='purple', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_sound_owner["time_total"]), color='grey', linestyle='dashed', linewidth=5)

# %%
# Distplot with means comparing all communications of the no opa deployment 
# (dotted) with all communications of the bulked up 1000 deployment (dashed)
plt.figure()
ax1 = sns.distplot(df_no_opa_owner_vfx1["time_total"], color='blue')
ax2 = sns.distplot(df_no_opa_vfx1_vfx2["time_total"], color='green')
ax3 = sns.distplot(df_no_opa_vfx1_vfx3["time_total"], color='yellow')
ax4 = sns.distplot(df_no_opa_vfx2_color["time_total"], color='orange')
ax5 = sns.distplot(df_no_opa_vfx3_sound["time_total"], color='red')
ax6 = sns.distplot(df_no_opa_color_hdr["time_total"], color='pink')
ax7 = sns.distplot(df_no_opa_hdr_owner["time_total"], color='purple')
ax8 = sns.distplot(df_no_opa_sound_owner["time_total"], color='grey')
plt.axvline(np.mean(df_no_opa_owner_vfx1["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_no_opa_vfx1_vfx2["time_total"]), color='green', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_no_opa_vfx1_vfx3["time_total"]), color='yellow', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_no_opa_vfx2_color["time_total"]), color='orange', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_no_opa_vfx3_sound["time_total"]), color='red', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_no_opa_color_hdr["time_total"]), color='pink', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_no_opa_hdr_owner["time_total"]), color='purple', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_no_opa_sound_owner["time_total"]), color='grey', linestyle='dotted', linewidth=5)
ax1 = sns.distplot(df_opa_bulked_up_1000_owner_vfx1["time_total"], color='blue')
ax2 = sns.distplot(df_opa_bulked_up_1000_vfx1_vfx2["time_total"], color='green')
ax3 = sns.distplot(df_opa_bulked_up_1000_vfx1_vfx3["time_total"], color='yellow')
ax4 = sns.distplot(df_opa_bulked_up_1000_vfx2_color["time_total"], color='orange')
ax5 = sns.distplot(df_opa_bulked_up_1000_vfx3_sound["time_total"], color='red')
ax6 = sns.distplot(df_opa_bulked_up_1000_color_hdr["time_total"], color='pink')
ax7 = sns.distplot(df_opa_bulked_up_1000_hdr_owner["time_total"], color='purple')
ax8 = sns.distplot(df_opa_bulked_up_1000_sound_owner["time_total"], color='grey')
plt.axvline(np.mean(df_opa_bulked_up_1000_owner_vfx1["time_total"]), color='blue', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx1_vfx2["time_total"]), color='green', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx1_vfx3["time_total"]), color='yellow', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx2_color["time_total"]), color='orange', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx3_sound["time_total"]), color='red', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_color_hdr["time_total"]), color='pink', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_hdr_owner["time_total"]), color='purple', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_sound_owner["time_total"]), color='grey', linestyle='dashed', linewidth=5)

# %%
# Distplot with means comparing all communications of the opa minimal deployment 
# (dotted) with all communications of the bulked up 1000 deployment (dashed)
plt.figure()
ax1 = sns.distplot(df_opa_minimal_owner_vfx1["time_total"], color='blue')
ax2 = sns.distplot(df_opa_minimal_vfx1_vfx2["time_total"], color='green')
ax3 = sns.distplot(df_opa_minimal_vfx1_vfx3["time_total"], color='yellow')
ax4 = sns.distplot(df_opa_minimal_vfx2_color["time_total"], color='orange')
ax5 = sns.distplot(df_opa_minimal_vfx3_sound["time_total"], color='red')
ax6 = sns.distplot(df_opa_minimal_color_hdr["time_total"], color='pink')
ax7 = sns.distplot(df_opa_minimal_hdr_owner["time_total"], color='purple')
ax8 = sns.distplot(df_opa_minimal_sound_owner["time_total"], color='grey')
plt.axvline(np.mean(df_opa_minimal_owner_vfx1["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_vfx1_vfx2["time_total"]), color='green', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_vfx1_vfx3["time_total"]), color='yellow', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_vfx2_color["time_total"]), color='orange', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_vfx3_sound["time_total"]), color='red', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_color_hdr["time_total"]), color='pink', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_hdr_owner["time_total"]), color='purple', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_sound_owner["time_total"]), color='grey', linestyle='dotted', linewidth=5)
bx1 = sns.distplot(df_opa_bulked_up_1000_owner_vfx1["time_total"], color='blue')
bx2 = sns.distplot(df_opa_bulked_up_1000_vfx1_vfx2["time_total"], color='green')
bx3 = sns.distplot(df_opa_bulked_up_1000_vfx1_vfx3["time_total"], color='yellow')
bx4 = sns.distplot(df_opa_bulked_up_1000_vfx2_color["time_total"], color='orange')
bx5 = sns.distplot(df_opa_bulked_up_1000_vfx3_sound["time_total"], color='red')
bx6 = sns.distplot(df_opa_bulked_up_1000_color_hdr["time_total"], color='pink')
bx7 = sns.distplot(df_opa_bulked_up_1000_hdr_owner["time_total"], color='purple')
bx8 = sns.distplot(df_opa_bulked_up_1000_sound_owner["time_total"], color='grey')
plt.axvline(np.mean(df_opa_bulked_up_1000_owner_vfx1["time_total"]), color='blue', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx1_vfx2["time_total"]), color='green', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx1_vfx3["time_total"]), color='yellow', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx2_color["time_total"]), color='orange', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx3_sound["time_total"]), color='red', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_color_hdr["time_total"]), color='pink', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_hdr_owner["time_total"]), color='purple', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_sound_owner["time_total"]), color='grey', linestyle='dashed', linewidth=5)

# %%
# Separating communications by intra/inter region
df_no_opa_intra_region = df_no_opa_vfx1_vfx2
df_no_opa_intra_region = df_no_opa_intra_region.append(df_no_opa_vfx1_vfx2)
df_no_opa_intra_region = df_no_opa_intra_region.append(df_no_opa_vfx1_vfx3)
df_no_opa_intra_region = df_no_opa_intra_region.append(df_no_opa_vfx2_color)

df_no_opa_inter_region = df_no_opa_vfx3_sound
df_no_opa_inter_region = df_no_opa_inter_region.append(df_no_opa_color_hdr)
df_no_opa_inter_region = df_no_opa_inter_region.append(df_no_opa_hdr_owner)
df_no_opa_inter_region = df_no_opa_inter_region.append(df_no_opa_sound_owner)


df_opa_all_allow_intra_region = df_opa_all_allow_vfx1_vfx2
df_opa_all_allow_intra_region = df_opa_all_allow_intra_region.append(df_opa_all_allow_vfx1_vfx2)
df_opa_all_allow_intra_region = df_opa_all_allow_intra_region.append(df_opa_all_allow_vfx1_vfx3)
df_opa_all_allow_intra_region = df_opa_all_allow_intra_region.append(df_opa_all_allow_vfx2_color)

df_opa_all_allow_inter_region = df_opa_all_allow_vfx3_sound
df_opa_all_allow_inter_region = df_opa_all_allow_inter_region.append(df_opa_all_allow_color_hdr)
df_opa_all_allow_inter_region = df_opa_all_allow_inter_region.append(df_opa_all_allow_hdr_owner)
df_opa_all_allow_inter_region = df_opa_all_allow_inter_region.append(df_opa_all_allow_sound_owner)


df_opa_minimal_intra_region = df_opa_minimal_vfx1_vfx2
df_opa_minimal_intra_region = df_opa_minimal_intra_region.append(df_opa_minimal_vfx1_vfx2)
df_opa_minimal_intra_region = df_opa_minimal_intra_region.append(df_opa_minimal_vfx1_vfx3)
df_opa_minimal_intra_region = df_opa_minimal_intra_region.append(df_opa_minimal_vfx2_color)

df_opa_minimal_inter_region = df_opa_minimal_vfx3_sound
df_opa_minimal_inter_region = df_opa_minimal_inter_region.append(df_opa_minimal_color_hdr)
df_opa_minimal_inter_region = df_opa_minimal_inter_region.append(df_opa_minimal_hdr_owner)
df_opa_minimal_inter_region = df_opa_minimal_inter_region.append(df_opa_minimal_sound_owner)


df_opa_bulked_up_100_intra_region = df_opa_bulked_up_100_vfx1_vfx2
df_opa_bulked_up_100_intra_region = df_opa_bulked_up_100_intra_region.append(df_opa_bulked_up_100_vfx1_vfx2)
df_opa_bulked_up_100_intra_region = df_opa_bulked_up_100_intra_region.append(df_opa_bulked_up_100_vfx1_vfx3)
df_opa_bulked_up_100_intra_region = df_opa_bulked_up_100_intra_region.append(df_opa_bulked_up_100_vfx2_color)

df_opa_bulked_up_100_inter_region = df_opa_bulked_up_100_vfx3_sound
df_opa_bulked_up_100_inter_region = df_opa_bulked_up_100_inter_region.append(df_opa_bulked_up_100_color_hdr)
df_opa_bulked_up_100_inter_region = df_opa_bulked_up_100_inter_region.append(df_opa_bulked_up_100_hdr_owner)
df_opa_bulked_up_100_inter_region = df_opa_bulked_up_100_inter_region.append(df_opa_bulked_up_100_sound_owner)


df_opa_bulked_up_1000_intra_region = df_opa_bulked_up_1000_vfx1_vfx2
df_opa_bulked_up_1000_intra_region = df_opa_bulked_up_1000_intra_region.append(df_opa_bulked_up_1000_vfx1_vfx2)
df_opa_bulked_up_1000_intra_region = df_opa_bulked_up_1000_intra_region.append(df_opa_bulked_up_1000_vfx1_vfx3)
df_opa_bulked_up_1000_intra_region = df_opa_bulked_up_1000_intra_region.append(df_opa_bulked_up_1000_vfx2_color)

df_opa_bulked_up_1000_inter_region = df_opa_bulked_up_1000_vfx3_sound
df_opa_bulked_up_1000_inter_region = df_opa_bulked_up_1000_inter_region.append(df_opa_bulked_up_1000_color_hdr)
df_opa_bulked_up_1000_inter_region = df_opa_bulked_up_1000_inter_region.append(df_opa_bulked_up_1000_hdr_owner)
df_opa_bulked_up_1000_inter_region = df_opa_bulked_up_1000_inter_region.append(df_opa_bulked_up_1000_sound_owner)

# %%
# Intra/Inter region on OPA minimal
plt.figure()
ax1 = sns.distplot(df_opa_minimal_intra_region["time_total"], color='blue')
ax2 = sns.distplot(df_opa_minimal_inter_region["time_total"], color='orange')
plt.axvline(np.mean(df_opa_minimal_intra_region["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_inter_region["time_total"]), color='orange', linestyle='dotted', linewidth=5)

# %%
# Intra region minimal vs bulked up 1000
plt.figure()
ax1 = sns.distplot(df_opa_minimal_intra_region["time_total"], color='blue')
ax2 = sns.distplot(df_opa_bulked_up_1000_intra_region["time_total"], color='orange')
plt.axvline(np.mean(df_opa_minimal_intra_region["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_intra_region["time_total"]), color='orange', linestyle='dotted', linewidth=5)

# %%
# Inter region minimal vs bulked up 1000
plt.figure()
ax1 = sns.distplot(df_opa_minimal_inter_region["time_total"], color='blue')
ax2 = sns.distplot(df_opa_bulked_up_1000_inter_region["time_total"], color='orange')
plt.axvline(np.mean(df_opa_minimal_inter_region["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_inter_region["time_total"]), color='orange', linestyle='dotted', linewidth=5)

# %%
# Owner -> VFX1 across policy deployments
plt.figure()
ax1 = sns.distplot(df_no_opa_owner_vfx1["time_total"], color='blue')
ax2 = sns.distplot(df_opa_all_allow_owner_vfx1["time_total"], color='green')
ax3 = sns.distplot(df_opa_minimal_owner_vfx1["time_total"], color='yellow')
ax4 = sns.distplot(df_opa_bulked_up_100_owner_vfx1["time_total"], color='orange')
ax5 = sns.distplot(df_opa_bulked_up_1000_owner_vfx1["time_total"], color='red')
plt.axvline(np.mean(df_no_opa_owner_vfx1["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_all_allow_owner_vfx1["time_total"]), color='green', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_owner_vfx1["time_total"]), color='yellow', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_100_owner_vfx1["time_total"]), color='orange', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_owner_vfx1["time_total"]), color='red', linestyle='dotted', linewidth=5)

# %%
# VFX1 -> VFX2 across policy deployments
plt.figure()
ax1 = sns.distplot(df_no_opa_vfx1_vfx2["time_total"], color='blue')
ax2 = sns.distplot(df_opa_all_allow_vfx1_vfx2["time_total"], color='green')
ax3 = sns.distplot(df_opa_minimal_vfx1_vfx2["time_total"], color='yellow')
ax4 = sns.distplot(df_opa_bulked_up_100_vfx1_vfx2["time_total"], color='orange')
ax5 = sns.distplot(df_opa_bulked_up_1000_vfx1_vfx2["time_total"], color='red')
plt.axvline(np.mean(df_no_opa_vfx1_vfx2["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_all_allow_vfx1_vfx2["time_total"]), color='green', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_vfx1_vfx2["time_total"]), color='yellow', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_100_vfx1_vfx2["time_total"]), color='orange', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx1_vfx2["time_total"]), color='red', linestyle='dotted', linewidth=5)

# %%
# VFX1 -> VFX3 across policy deployments
plt.figure()
ax1 = sns.distplot(df_no_opa_vfx1_vfx3["time_total"], color='blue')
ax2 = sns.distplot(df_opa_all_allow_vfx1_vfx3["time_total"], color='green')
ax3 = sns.distplot(df_opa_minimal_vfx1_vfx3["time_total"], color='yellow')
ax4 = sns.distplot(df_opa_bulked_up_100_vfx1_vfx3["time_total"], color='orange')
ax5 = sns.distplot(df_opa_bulked_up_1000_vfx1_vfx3["time_total"], color='red')
plt.axvline(np.mean(df_no_opa_vfx1_vfx3["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_all_allow_vfx1_vfx3["time_total"]), color='green', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_vfx1_vfx3["time_total"]), color='yellow', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_100_vfx1_vfx3["time_total"]), color='orange', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx1_vfx3["time_total"]), color='red', linestyle='dotted', linewidth=5)

# %%
# VX2 -> Color across policy deployments
plt.figure()
ax1 = sns.distplot(df_no_opa_vfx2_color["time_total"], color='blue')
ax1 = sns.distplot(df_opa_all_allow_vfx2_color["time_total"], color='green')
ax1 = sns.distplot(df_opa_minimal_vfx2_color["time_total"], color='yellow')
ax1 = sns.distplot(df_opa_bulked_up_100_vfx2_color["time_total"], color='orange')
ax1 = sns.distplot(df_opa_bulked_up_1000_vfx2_color["time_total"], color='red')
plt.axvline(np.mean(df_no_opa_vfx2_color["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_all_allow_vfx2_color["time_total"]), color='green', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_vfx2_color["time_total"]), color='yellow', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_100_vfx2_color["time_total"]), color='orange', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx2_color["time_total"]), color='red', linestyle='dotted', linewidth=5)

# %%
# VFX3 -> Sound across policy deployments
plt.figure()
ax1 = sns.distplot(df_no_opa_vfx3_sound["time_total"], color='blue')
ax1 = sns.distplot(df_opa_all_allow_vfx3_sound["time_total"], color='green')
ax1 = sns.distplot(df_opa_minimal_vfx3_sound["time_total"], color='yellow')
ax1 = sns.distplot(df_opa_bulked_up_100_vfx3_sound["time_total"], color='orange')
ax1 = sns.distplot(df_opa_bulked_up_1000_vfx3_sound["time_total"], color='red')
plt.axvline(np.mean(df_no_opa_vfx3_sound["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_all_allow_vfx3_sound["time_total"]), color='green', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_vfx3_sound["time_total"]), color='yellow', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_100_vfx3_sound["time_total"]), color='orange', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_vfx3_sound["time_total"]), color='red', linestyle='dotted', linewidth=5)

# %%
# Color -> HDR across policy deployments
plt.figure()
ax1 = sns.distplot(df_no_opa_color_hdr["time_total"], color='blue')
ax1 = sns.distplot(df_opa_all_allow_color_hdr["time_total"], color='green')
ax1 = sns.distplot(df_opa_minimal_color_hdr["time_total"], color='yellow')
ax1 = sns.distplot(df_opa_bulked_up_100_color_hdr["time_total"], color='orange')
ax1 = sns.distplot(df_opa_bulked_up_1000_color_hdr["time_total"], color='red')
plt.axvline(np.mean(df_no_opa_color_hdr["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_all_allow_color_hdr["time_total"]), color='green', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_color_hdr["time_total"]), color='yellow', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_100_color_hdr["time_total"]), color='orange', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_color_hdr["time_total"]), color='red', linestyle='dotted', linewidth=5)

# %%
# HDR -> Owner across policy deployments
plt.figure()
ax1 = sns.distplot(df_no_opa_hdr_owner["time_total"], color='blue')
ax1 = sns.distplot(df_opa_all_allow_hdr_owner["time_total"], color='green')
ax1 = sns.distplot(df_opa_minimal_hdr_owner["time_total"], color='yellow')
ax1 = sns.distplot(df_opa_bulked_up_100_hdr_owner["time_total"], color='orange')
ax1 = sns.distplot(df_opa_bulked_up_1000_hdr_owner["time_total"], color='red')
plt.axvline(np.mean(df_no_opa_hdr_owner["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_all_allow_hdr_owner["time_total"]), color='green', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_hdr_owner["time_total"]), color='yellow', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_100_hdr_owner["time_total"]), color='orange', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_hdr_owner["time_total"]), color='red', linestyle='dotted', linewidth=5)

# %%
# Sound -> Owner across policy deployments
plt.figure()
ax1 = sns.distplot(df_no_opa_sound_owner["time_total"], color='blue')
ax1 = sns.distplot(df_opa_all_allow_sound_owner["time_total"], color='green')
ax1 = sns.distplot(df_opa_minimal_sound_owner["time_total"], color='yellow')
ax1 = sns.distplot(df_opa_bulked_up_100_sound_owner["time_total"], color='orange')
ax1 = sns.distplot(df_opa_bulked_up_1000_sound_owner["time_total"], color='red')
plt.axvline(np.mean(df_no_opa_sound_owner["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_all_allow_sound_owner["time_total"]), color='green', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_sound_owner["time_total"]), color='yellow', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_100_sound_owner["time_total"]), color='orange', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_sound_owner["time_total"]), color='red', linestyle='dotted', linewidth=5)

# %%
# Intra region on all policy deployments
plt.figure()
ax1 = sns.distplot(df_no_opa_intra_region["time_total"], color='blue')
ax2 = sns.distplot(df_opa_all_allow_intra_region["time_total"], color='green')
ax3 = sns.distplot(df_opa_minimal_intra_region["time_total"], color='yellow')
ax4 = sns.distplot(df_opa_bulked_up_100_intra_region["time_total"], color='orange')
ax5 = sns.distplot(df_opa_bulked_up_1000_intra_region["time_total"], color='red')

plt.axvline(np.mean(df_no_opa_intra_region["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_all_allow_intra_region["time_total"]), color='green', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_intra_region["time_total"]), color='yellow', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_100_intra_region["time_total"]), color='orange', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_intra_region["time_total"]), color='red', linestyle='dotted', linewidth=5)

# %%
# Inter region on all policy deployments
plt.figure()
ax1 = sns.distplot(df_no_opa_inter_region["time_total"], color='blue')
ax2 = sns.distplot(df_opa_all_allow_inter_region["time_total"], color='green')
ax3 = sns.distplot(df_opa_minimal_inter_region["time_total"], color='yellow')
ax4 = sns.distplot(df_opa_bulked_up_100_inter_region["time_total"], color='orange')
ax5 = sns.distplot(df_opa_bulked_up_1000_inter_region["time_total"], color='red')

plt.axvline(np.mean(df_no_opa_inter_region["time_total"]), color='blue', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_all_allow_inter_region["time_total"]), color='green', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_minimal_inter_region["time_total"]), color='yellow', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_100_inter_region["time_total"]), color='orange', linestyle='dotted', linewidth=5)
plt.axvline(np.mean(df_opa_bulked_up_1000_inter_region["time_total"]), color='red', linestyle='dotted', linewidth=5)

# %%
## Intra-region data in one DataFrame
df_intra = pd.DataFrame(df_no_opa_intra_region["time_total"].rename("no_opa")) # Add a Series and convert to DataFrame
df_intra = df_intra.assign(opa_all_allow=df_opa_all_allow_intra_region["time_total"].values)
df_intra = df_intra.assign(opa_minimal=df_opa_minimal_intra_region["time_total"].values)
df_intra = df_intra.assign(opa_bulked_up_100=df_opa_bulked_up_100_intra_region["time_total"].values)
df_intra = df_intra.assign(opa_bulked_up_1000=df_opa_bulked_up_1000_intra_region["time_total"].values)

print(df_intra)

## Inter-region data in one DataFrame
df_inter = pd.DataFrame(df_no_opa_inter_region["time_total"].rename("no_opa")) # Add a Series and convert to DataFrame
df_inter = df_inter.assign(opa_all_allow=df_opa_all_allow_inter_region["time_total"].values)
df_inter = df_inter.assign(opa_minimal=df_opa_minimal_inter_region["time_total"].values)
df_inter = df_inter.assign(opa_bulked_up_100=df_opa_bulked_up_100_inter_region["time_total"].values)
df_inter = df_inter.assign(opa_bulked_up_1000=df_opa_bulked_up_1000_inter_region["time_total"].values)

print(df_inter)

# %%
df_intra.describe()
df_intra.columns = ['no OPA', 'all allow', 'minimal', '+100', '+1000']

# %%
df_intra = df_intra*1000
df_intra.describe()

# %%
# Boxplot of intra-region request times by policy deployment
plt.figure()
sns.set_style("whitegrid")

boxprops = dict(linestyle='-', linewidth=4, color='k')
medianprops = dict(linestyle='-', linewidth=4, color='k')

ax = df_intra.boxplot(color="black", boxprops=boxprops, medianprops=medianprops)
ax.grid(axis='y')
plt.grid(b=None)
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
plt.ylabel("Request duration (ms)", fontsize=40)

plt.tight_layout()
plt.savefig("figures/request-time.pdf")

# %%
# Boxplot of inter-region request times by policy deployment
df_inter.boxplot()

# %% [markdown]
# # ANOVA
# ***
# ## Intra-region
# ***
# ### Remove or winsorize outliers

# %%
# Remove or winsorize outliers

# %% [markdown]
# ### ANOVA

# %%
# Some values to compute the ANOVA
k = 5 # Number of levels
n = equal_sample_size * k # Total number of observations
alpha = 0.05
# degrees of freedom
df_between = k - 1 # df for numerator
df_within = n - k # df for denominator
df_total = n - 1


# ANOVA by numbers
import scipy.stats as stats
# stats f_oneway functions takes the groups as input and returns F and P-value
fvalue, pvalue = stats.f_oneway(df_intra['no_opa'], df_intra['opa_all_allow'], df_intra['opa_minimal'],df_intra['opa_bulked_up_100'], df_intra['opa_bulked_up_1000'])
print("F-value = {}  -  p-value = {}\n".format(fvalue, pvalue))


# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols

# reshape the d dataframe suitable for statsmodels package 
d_melt = pd.melt(df_intra.reset_index(), id_vars=['index'], value_vars=['no_opa', 'opa_all_allow', 'opa_minimal', 'opa_bulked_up_100', 'opa_bulked_up_1000'])
# replace column names
d_melt.columns = ['index', 'policy', 'time_total']
print(d_melt)

# Ordinary Least Squares (OLS) model
model = ols('time_total ~ C(policy)', data=d_melt).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table

# %%
# Partial eta squared
partial_eta_squared = 0.006311 / (0.006311 + 0.003446)
partial_eta_squared

# %% [markdown]
# ### Post-hoc analysis

# %%
# Post-hoc analysis

# load packages
from pingouin import pairwise_tukey
# perform multiple pairwise comparison (Tukey HSD)
# for unbalanced (unequal sample size) data, pairwise_tukey uses Tukey-Kramer test
m_comp = pairwise_tukey(data=d_melt, dv='time_total', between='policy', effsize='cohen')
m_comp

# %%
# Other Tukey
from statsmodels.stats.multicomp import (pairwise_tukeyhsd,
                                         MultiComparison)

# Set up the data for comparison (creates a specialised object)
MultiComp = MultiComparison(d_melt['time_total'],
                            d_melt['policy'])

# Print the comparisons
MultiComp.tukeyhsd().summary()

# %% [markdown]
# ### Test ANOVA assumptions
#
# #### Test data (residuals) for normality (Shapiro-Wilks test)

# %%
# Test data (residuals) for normality (Shapiro-Wilks test)

# load packages
import scipy.stats as stats
w, pvalue = stats.shapiro(model.resid)
print("W = {}  -  p-value = {}\n".format(w, pvalue))

# %% [markdown]
# #### Test the homogeneity of variance (Levene or Bartlett's test for equality of variances)

# %%
# As long as N > 30, ANOVA is robust to violation of this rule

# load packages
import scipy.stats as stats
w, pvalue = stats.bartlett(df_intra['no_opa'], df_intra['opa_all_allow'], df_intra['opa_minimal'],df_intra['opa_bulked_up_100'], df_intra['opa_bulked_up_1000'])
print("W = {}  -  p-value = {}\n".format(w, pvalue))

# %% [markdown]
# ## Inter-region
# ***
# ### Remove or winsorize outliers

# %%
# Remove or winsorize outliers

# %% [markdown]
# ### ANOVA

# %%
# Some values to compute the ANOVA
k = 5 # Number of levels
n = equal_sample_size * k # Total number of observations
alpha = 0.05
# degrees of freedom
df_between = k - 1 # df for numerator
df_within = n - k # df for denominator
df_total = n - 1


# ANOVA by numbers
import scipy.stats as stats
# stats f_oneway functions takes the groups as input and returns F and P-value
fvalue, pvalue = stats.f_oneway(df_inter['no_opa'], df_inter['opa_all_allow'], df_inter['opa_minimal'],df_inter['opa_bulked_up_100'], df_inter['opa_bulked_up_1000'])
print("F-value = {}  -  p-value = {}\n".format(fvalue, pvalue))


# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols

# reshape the d dataframe suitable for statsmodels package 
d_melt = pd.melt(df_inter.reset_index(), id_vars=['index'], value_vars=['no_opa', 'opa_all_allow', 'opa_minimal', 'opa_bulked_up_100', 'opa_bulked_up_1000'])
# replace column names
d_melt.columns = ['index', 'policy', 'time_total']
print(d_melt)

# Ordinary Least Squares (OLS) model
model = ols('time_total ~ C(policy)', data=d_melt).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table

# %%
# Partial eta squared
partial_eta_squared = 0.006901 / (0.006901 + 0.090084 )
partial_eta_squared

# %% [markdown]
# ### Post-hoc analysis

# %%
# Post-hoc analysis

# load packages
from pingouin import pairwise_tukey
# perform multiple pairwise comparison (Tukey HSD)
# for unbalanced (unequal sample size) data, pairwise_tukey uses Tukey-Kramer test
m_comp = pairwise_tukey(data=d_melt, dv='time_total', between='policy', effsize='cohen')
m_comp

# %%
# Other Tukey
from statsmodels.stats.multicomp import (pairwise_tukeyhsd,
                                         MultiComparison)

# Set up the data for comparison (creates a specialised object)
MultiComp = MultiComparison(d_melt['time_total'],
                            d_melt['policy'])

# Print the comparisons
MultiComp.tukeyhsd().summary()

# %% [markdown]
# ### Test ANOVA assumptions
#
# #### Test data (residuals) for normality (Shapiro-Wilks test)

# %%
# Test data (residuals) for normality (Shapiro-Wilks test)

# load packages
import scipy.stats as stats
w, pvalue = stats.shapiro(model.resid)
print("W = {}  -  p-value = {}\n".format(w, pvalue))

# %% [markdown]
# #### Test the homogeneity of variance (Levene or Bartlett's test for equality of variances)

# %%
# As long as N > 30, ANOVA is robust to violation of this rule

# load packages
import scipy.stats as stats
w, pvalue = stats.bartlett(df_inter['no_opa'], df_inter['opa_all_allow'], df_inter['opa_minimal'],df_inter['opa_bulked_up_100'], df_inter['opa_bulked_up_1000'])
print("W = {}  -  p-value = {}\n".format(w, pvalue))
