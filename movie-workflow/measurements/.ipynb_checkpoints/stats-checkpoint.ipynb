# %%
import ast
import pandas as pd

opa_data = []
with open("wfs-opa-measures.dat", 'r') as f:
    for line in f:
        opa_data.append(ast.literal_eval(line))

for line in opa_data:
    print(line)
# Out:
# ('owner', '2020-06-10T16:46:09Z', '2020-06-10T16:46:11Z', '2020-06-10T16:46:15Z', '2020-06-10T16:46:15Z', 6.0)
# ('vfx-1', '2020-06-10T16:46:14Z', '2020-06-10T16:46:16Z', '2020-06-10T16:46:23Z', '2020-06-10T16:46:23Z', 9.0)
# ('vfx-2', '2020-06-10T16:46:51Z', '2020-06-10T16:46:54Z', '2020-06-10T16:46:58Z', '2020-06-10T16:46:58Z', 7.0)
# ('vfx-3', '2020-06-10T16:47:32Z', '2020-06-10T16:47:34Z', '2020-06-10T16:47:40Z', '2020-06-10T16:47:40Z', 8.0)
# ('color', '2020-06-10T16:48:12Z', '2020-06-10T16:48:14Z', '2020-06-10T16:48:21Z', '2020-06-10T16:48:21Z', 9.0)
# ('sound', '2020-06-10T16:48:56Z', '2020-06-10T16:48:58Z', '2020-06-10T16:49:05Z', '2020-06-10T16:49:05Z', 9.0)
# ('hdr', '2020-06-10T16:49:33Z', '2020-06-10T16:49:35Z', '2020-06-10T16:49:40Z', '2020-06-10T16:49:40Z', 7.0)

# %%
no_opa_data = []
with open("wfs-no-opa-measures.dat", 'r') as f:
    for line in f:
        no_opa_data.append(ast.literal_eval(line))

for line in no_opa_data:
    print(line)

# %%
df_opa = pd.DataFrame(opa_data, columns=['name', 'pod_scheduled', 'initialized', 'containers_ready', 'ready', 'startup'])
df_opa
# Out:
#     name         pod_scheduled           initialized      containers_ready  \
# 0  owner  2020-06-10T16:46:09Z  2020-06-10T16:46:11Z  2020-06-10T16:46:15Z
# 1  vfx-1  2020-06-10T16:46:14Z  2020-06-10T16:46:16Z  2020-06-10T16:46:23Z
# 2  vfx-2  2020-06-10T16:46:51Z  2020-06-10T16:46:54Z  2020-06-10T16:46:58Z
# 3  vfx-3  2020-06-10T16:47:32Z  2020-06-10T16:47:34Z  2020-06-10T16:47:40Z
# 4  color  2020-06-10T16:48:12Z  2020-06-10T16:48:14Z  2020-06-10T16:48:21Z
# 5  sound  2020-06-10T16:48:56Z  2020-06-10T16:48:58Z  2020-06-10T16:49:05Z
# 6    hdr  2020-06-10T16:49:33Z  2020-06-10T16:49:35Z  2020-06-10T16:49:40Z
#
#                   ready  startup
# 0  2020-06-10T16:46:15Z      6.0
# 1  2020-06-10T16:46:23Z      9.0
# 2  2020-06-10T16:46:58Z      7.0
# 3  2020-06-10T16:47:40Z      8.0
# 4  2020-06-10T16:48:21Z      9.0
# 5  2020-06-10T16:49:05Z      9.0
# 6  2020-06-10T16:49:40Z      7.0

# %%
df_no_opa = pd.DataFrame(no_opa_data, columns=['name', 'pod_scheduled', 'initialized', 'containers_ready', 'ready', 'startup'])
df_no_opa

# %%
# Filters
is_owner = df_opa['name'] == "owner"
is_vfx_1 = df_opa['name'] == "vfx-1"
is_vfx_2 = df_opa['name'] == "vfx-2"
is_vfx_3 = df_opa['name'] == "vfx-3"
is_color = df_opa['name'] == "color"
is_sound = df_opa['name'] == "sound"
is_hdr   = df_opa['name'] == "hdr"

# Filtered dfs by pod
df_opa_owner = df_opa[is_owner]
df_opa_vfx_1 = df_opa[is_vfx_1]
df_opa_vfx_2 = df_opa[is_vfx_2]
df_opa_vfx_3 = df_opa[is_vfx_3]
df_opa_color = df_opa[is_color]
df_opa_sound = df_opa[is_sound]
df_opa_hdr   = df_opa[is_hdr]

dfs_opa_pods = [df_opa_owner, df_opa_vfx_1, df_opa_vfx_2, df_opa_vfx_3, df_opa_color, df_opa_sound, df_opa_hdr]

# %%
# Filters
is_owner = df_no_opa['name'] == "owner"
is_vfx_1 = df_no_opa['name'] == "vfx-1"
is_vfx_2 = df_no_opa['name'] == "vfx-2"
is_vfx_3 = df_no_opa['name'] == "vfx-3"
is_color = df_no_opa['name'] == "color"
is_sound = df_no_opa['name'] == "sound"
is_hdr   = df_no_opa['name'] == "hdr"

# Filtered dfs by pod
df_no_opa_owner = df_no_opa[is_owner]
df_no_opa_vfx_1 = df_no_opa[is_vfx_1]
df_no_opa_vfx_2 = df_no_opa[is_vfx_2]
df_no_opa_vfx_3 = df_no_opa[is_vfx_3]
df_no_opa_color = df_no_opa[is_color]
df_no_opa_sound = df_no_opa[is_sound]
df_no_opa_hdr   = df_no_opa[is_hdr]

dfs_no_opa_pods = [df_no_opa_owner, df_no_opa_vfx_1, df_no_opa_vfx_2, df_no_opa_vfx_3, df_no_opa_color, df_no_opa_sound, df_no_opa_hdr]

# %%
df_opa.describe()
# Out:
#         startup
# count  7.000000
# mean   7.857143
# std    1.214986
# min    6.000000
# 25%    7.000000
# 50%    8.000000
# 75%    9.000000
# max    9.000000

# %%
df_no_opa.describe()

# %%
for df in dfs_opa_pods:
    print(df["name"].head(1))
    print(df.describe())
    print('\n')
# Out:
# 0    owner
# Name: name, dtype: object
#        startup
# count      1.0
# mean       6.0
# std        NaN
# min        6.0
# 25%        6.0
# 50%        6.0
# 75%        6.0
# max        6.0
#
#
# 1    vfx-1
# Name: name, dtype: object
#        startup
# count      1.0
# mean       9.0
# std        NaN
# min        9.0
# 25%        9.0
# 50%        9.0
# 75%        9.0
# max        9.0
#
#
# 2    vfx-2
# Name: name, dtype: object
#        startup
# count      1.0
# mean       7.0
# std        NaN
# min        7.0
# 25%        7.0
# 50%        7.0
# 75%        7.0
# max        7.0
#
#
# 3    vfx-3
# Name: name, dtype: object
#        startup
# count      1.0
# mean       8.0
# std        NaN
# min        8.0
# 25%        8.0
# 50%        8.0
# 75%        8.0
# max        8.0
#
#
# 4    color
# Name: name, dtype: object
#        startup
# count      1.0
# mean       9.0
# std        NaN
# min        9.0
# 25%        9.0
# 50%        9.0
# 75%        9.0
# max        9.0
#
#
# 5    sound
# Name: name, dtype: object
#        startup
# count      1.0
# mean       9.0
# std        NaN
# min        9.0
# 25%        9.0
# 50%        9.0
# 75%        9.0
# max        9.0
#
#
# 6    hdr
# Name: name, dtype: object
#        startup
# count      1.0
# mean       7.0
# std        NaN
# min        7.0
# 25%        7.0
# 50%        7.0
# 75%        7.0
# max        7.0

# %%
for df in dfs_no_opa_pods:
    print(df["name"].head(1))
    print(df.describe())
    print('\n')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
from pylab import rcParams
from scipy.stats import f_oneway
from scipy.stats import ttest_ind

# T-test
N = 30
alpha = 0.05
power = 0.90


# %matplotlib inline
warnings.filterwarnings("ignore")
rcParams['figure.figsize'] = 20,10
rcParams['font.size'] = 30
sns.set()
np.random.seed(8)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-86-3fe37d12f1ef> in <module>
# ----> 1 import matplotlib.pyplot as plt
#       2 import numpy as np
#       3 from scipy import stats
#       4
#       5 # T-test
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
def plot_distribution(inp):
    plt.figure()
    ax = sns.distplot(inp)
    plt.axvline(np.mean(inp), color="k", linestyle="dashed", linewidth=5)
    _, max_ = plt.ylim()
    plt.text(
        inp.mean() + inp.mean() / 10,
        max_ - max_ / 10,
        "Mean: {:.2f}".format(inp.mean()),
    )
    return plt.figure
