# 1112  color  2020-06-11T23:26:45Z  2020-06-11T23:26:48Z  2020-06-11T23:26:52Z
# 1113  sound  2020-06-11T23:27:31Z  2020-06-11T23:27:34Z  2020-06-11T23:27:39Z
# 1114  sound  2020-06-11T23:29:42Z  2020-06-11T23:29:44Z  2020-06-11T23:29:49Z
#
#                      ready  startup
# 0     2020-06-10T22:47:15Z      7.0
# 1     2020-06-10T22:49:43Z      7.0
# 2     2020-06-10T22:51:06Z      8.0
# 3     2020-06-10T22:51:46Z      8.0
# 4     2020-06-10T22:41:50Z      7.0
# ...                    ...      ...
# 1110  2020-06-11T23:25:14Z      9.0
# 1111  2020-06-11T23:26:01Z      9.0
# 1112  2020-06-11T23:26:52Z      7.0
# 1113  2020-06-11T23:27:39Z      8.0
# 1114  2020-06-11T23:29:49Z      7.0
#
# [1115 rows x 6 columns]

# %%
# Filters
is_owner = df_opa['name'] == "owner"
is_vfx_1 = df_opa['name'] == "vfx-1"
is_vfx_2 = df_opa['name'] == "vfx-2"
is_vfx_3 = df_opa['name'] == "vfx-3"
is_color = df_opa['name'] == "color"
is_sound = df_opa['name'] == "sound"
is_hdr   = df_opa['name'] == "hdr"

# Filtered dfs by pod
df_opa_owner = df_opa[is_owner]
df_opa_vfx_1 = df_opa[is_vfx_1]
df_opa_vfx_2 = df_opa[is_vfx_2]
df_opa_vfx_3 = df_opa[is_vfx_3]
df_opa_color = df_opa[is_color]
df_opa_sound = df_opa[is_sound]
df_opa_hdr   = df_opa[is_hdr]

dfs_opa_pods = [df_opa_owner, df_opa_vfx_1, df_opa_vfx_2, df_opa_vfx_3, df_opa_color, df_opa_sound, df_opa_hdr]

# %%
# Filters
is_owner = df_no_opa['name'] == "owner"
is_vfx_1 = df_no_opa['name'] == "vfx-1"
is_vfx_2 = df_no_opa['name'] == "vfx-2"
is_vfx_3 = df_no_opa['name'] == "vfx-3"
is_color = df_no_opa['name'] == "color"
is_sound = df_no_opa['name'] == "sound"
is_hdr   = df_no_opa['name'] == "hdr"

# Filtered dfs by pod
df_no_opa_owner = df_no_opa[is_owner]
df_no_opa_vfx_1 = df_no_opa[is_vfx_1]
df_no_opa_vfx_2 = df_no_opa[is_vfx_2]
df_no_opa_vfx_3 = df_no_opa[is_vfx_3]
df_no_opa_color = df_no_opa[is_color]
df_no_opa_sound = df_no_opa[is_sound]
df_no_opa_hdr   = df_no_opa[is_hdr]

dfs_no_opa_pods = [df_no_opa_owner, df_no_opa_vfx_1, df_no_opa_vfx_2, df_no_opa_vfx_3, df_no_opa_color, df_no_opa_sound, df_no_opa_hdr]

# %%
df_opa.describe()
# Out:
#            startup
# count  1088.000000
# mean      7.834559
# std       1.026879
# min       5.000000
# 25%       7.000000
# 50%       8.000000
# 75%       8.000000
# max      14.000000

# %%
df_no_opa.describe()
# Out:
#            startup
# count  1115.000000
# mean      7.147085
# std       1.061772
# min       5.000000
# 25%       6.000000
# 50%       7.000000
# 75%       8.000000
# max      15.000000

# %%
for df in dfs_opa_pods:
    print(df["name"].head(1))
    print(df.describe())
    print('\n')
# Out:
# 0    owner
# Name: name, dtype: object
#           startup
# count  157.000000
# mean     7.445860
# std      1.027786
# min      5.000000
# 25%      7.000000
# 50%      7.000000
# 75%      8.000000
# max     14.000000
#
#
# 1    vfx-1
# Name: name, dtype: object
#           startup
# count  138.000000
# mean     8.173913
# std      1.003010
# min      6.000000
# 25%      8.000000
# 50%      8.000000
# 75%      9.000000
# max     12.000000
#
#
# 2    vfx-2
# Name: name, dtype: object
#          startup
# count  135.00000
# mean     8.22963
# std      1.05052
# min      6.00000
# 25%      8.00000
# 50%      8.00000
# 75%      9.00000
# max     11.00000
#
#
# 3    vfx-3
# Name: name, dtype: object
#           startup
# count  135.000000
# mean     8.451852
# std      0.990391
# min      6.000000
# 25%      8.000000
# 50%      8.000000
# 75%      9.000000
# max     11.000000
#
#
# 4    color
# Name: name, dtype: object
#           startup
# count  257.000000
# mean     7.478599
# std      0.918840
# min      5.000000
# 25%      7.000000
# 50%      7.000000
# 75%      8.000000
# max     10.000000
#
#
# 5    sound
# Name: name, dtype: object
#           startup
# count  130.000000
# mean     7.830769
# std      0.899082
# min      6.000000
# 25%      7.000000
# 50%      8.000000
# 75%      8.000000
# max     10.000000
#
#
# 6    hdr
# Name: name, dtype: object
#           startup
# count  136.000000
# mean     7.610294
# std      0.827068
# min      6.000000
# 25%      7.000000
# 50%      8.000000
# 75%      8.000000
# max     10.000000

# %%
for df in dfs_no_opa_pods:
    print(df["name"].head(1))
    print(df.describe())
    print('\n')
# Out:
# 0    owner
# Name: name, dtype: object
#          startup
# count  74.000000
# mean    7.229730
# std     0.884374
# min     5.000000
# 25%     7.000000
# 50%     7.000000
# 75%     8.000000
# max     9.000000
#
#
# 1    vfx-1
# Name: name, dtype: object
#          startup
# count  75.000000
# mean    7.026667
# std     1.013068
# min     5.000000
# 25%     6.000000
# 50%     7.000000
# 75%     8.000000
# max     9.000000
#
#
# 2    vfx-2
# Name: name, dtype: object
#          startup
# count  74.000000
# mean    7.513514
# std     1.036898
# min     5.000000
# 25%     7.000000
# 50%     7.000000
# 75%     8.000000
# max    10.000000
#
#
# 3    vfx-3
# Name: name, dtype: object
#          startup
# count  73.000000
# mean    7.438356
# std     0.865806
# min     6.000000
# 25%     7.000000
# 50%     7.000000
# 75%     8.000000
# max    10.000000
#
#
# 4    color
# Name: name, dtype: object
#           startup
# count  280.000000
# mean     6.571429
# std      0.992032
# min      5.000000
# 25%      6.000000
# 50%      7.000000
# 75%      7.000000
# max     14.000000
#
#
# 5    sound
# Name: name, dtype: object
#           startup
# count  264.000000
# mean     7.484848
# std      1.130193
# min      5.000000
# 25%      7.000000
# 50%      7.000000
# 75%      8.000000
# max     15.000000
#
#
# 6    hdr
# Name: name, dtype: object
#           startup
# count  275.000000
# mean     7.243636
# std      0.929399
# min      5.000000
# 25%      7.000000
# 50%      7.000000
# 75%      8.000000
# max     11.000000

# %%
# Adjust sample sizes for comparison
df_opa_owner = df_opa[is_owner].head(70)
df_opa_vfx_1 = df_opa[is_vfx_1].head(70)
df_opa_vfx_2 = df_opa[is_vfx_2].head(70)
df_opa_vfx_3 = df_opa[is_vfx_3].head(70)
df_opa_color = df_opa[is_color].head(70)
df_opa_sound = df_opa[is_sound].head(70)
df_opa_hdr   = df_opa[is_hdr].head(70)

df_no_opa_owner = df_no_opa[is_owner].head(70)
df_no_opa_vfx_1 = df_no_opa[is_vfx_1].head(70)
df_no_opa_vfx_2 = df_no_opa[is_vfx_2].head(70)
df_no_opa_vfx_3 = df_no_opa[is_vfx_3].head(70)
df_no_opa_color = df_no_opa[is_color].head(70)
df_no_opa_sound = df_no_opa[is_sound].head(70)
df_no_opa_hdr   = df_no_opa[is_hdr].head(70)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
from pylab import rcParams
from scipy.stats import f_oneway
from scipy.stats import ttest_ind

# %matplotlib inline
warnings.filterwarnings("ignore")
rcParams['figure.figsize'] = 20,10
rcParams['font.size'] = 30
sns.set()
np.random.seed(8)

# %%
def plot_distribution(inp):
    plt.figure()
    ax = sns.distplot(inp)
    plt.axvline(np.mean(inp), color="k", linestyle="dashed", linewidth=5)
    _, max_ = plt.ylim()
    plt.text(
        inp.mean() + inp.mean() / 10,
        max_ - max_ / 10,
        "Mean: {:.2f}".format(inp.mean()),
    )
    return plt.figure

# %%
plot_distribution(df_opa["startup"])
plot_distribution(df_no_opa["startup"])
# Out:
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
plt.figure()
ax1 = sns.distplot(df_opa["startup"])
ax2 = sns.distplot(df_no_opa["startup"])
plt.axvline(np.mean(df_opa["startup"]), color='b', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_no_opa["startup"]), color='orange', linestyle='dashed', linewidth=5)

# %%
for opa_idx, df_opa in enumerate(dfs_opa_pods):
    for no_opa_idx, df_no_opa in enumerate(dfs_no_opa_pods):
        if opa_idx == no_opa_idx:
            print(df_opa["name"].head(1))
            print(df_no_opa["name"].head(1))
            plt.figure()
            ax1 = sns.distplot(df_opa["startup"])
            ax2 = sns.distplot(df_no_opa["startup"])
            plt.axvline(np.mean(df_opa["startup"]), color='b', linestyle='dashed', linewidth=5)
            plt.axvline(np.mean(df_no_opa["startup"]), color='orange', linestyle='dashed', linewidth=5)
# Out:
# 0    owner
# Name: name, dtype: object
# 0    owner
# Name: name, dtype: object
# 1    vfx-1
# Name: name, dtype: object
# 1    vfx-1
# Name: name, dtype: object
# 2    vfx-2
# Name: name, dtype: object
# 2    vfx-2
# Name: name, dtype: object
# 3    vfx-3
# Name: name, dtype: object
# 3    vfx-3
# Name: name, dtype: object
# 4    color
# Name: name, dtype: object
# 4    color
# Name: name, dtype: object
# 5    sound
# Name: name, dtype: object
# 5    sound
# Name: name, dtype: object
# 6    hdr
# Name: name, dtype: object
# 6    hdr
# Name: name, dtype: object

# %%
def t_test(arr_1, arr_2, alpha, sample_size):
    stat, p = ttest_ind(arr_1, arr_2)
    print('t-statistic=%.3f, p=%.3f' % (stat, p))
    if p > alpha:
        print('Same distributions (fail to reject H0)')
    else:
        print('Different distributions (reject H0)')

# %%
t_test(df_opa["startup"], df_no_opa["startup"], alpha, len(df_opa.index))
print('\n')

for opa_idx, df_opa in enumerate(dfs_opa_pods):
    for no_opa_idx, df_no_opa in enumerate(dfs_no_opa_pods):
        if opa_idx == no_opa_idx:
            print(df_opa["name"].head(1))
            print(df_no_opa["name"].head(1))
            t_test(df_opa["startup"], df_no_opa["startup"], alpha, len(df_opa.index))
            print('\n')
# Out:
# t-statistic=3.900, p=0.000
# Different distributions (reject H0)
#
#
# 0    owner
# Name: name, dtype: object
# 0    owner
# Name: name, dtype: object
# t-statistic=1.557, p=0.121
# Same distributions (fail to reject H0)
#
#
# 1    vfx-1
# Name: name, dtype: object
# 1    vfx-1
# Name: name, dtype: object
# t-statistic=7.945, p=0.000
# Different distributions (reject H0)
#
#
# 2    vfx-2
# Name: name, dtype: object
# 2    vfx-2
# Name: name, dtype: object
# t-statistic=4.734, p=0.000
# Different distributions (reject H0)
#
#
# 3    vfx-3
# Name: name, dtype: object
# 3    vfx-3
# Name: name, dtype: object
# t-statistic=7.353, p=0.000
# Different distributions (reject H0)
#
#
# 4    color
# Name: name, dtype: object
# 4    color
# Name: name, dtype: object
# t-statistic=10.965, p=0.000
# Different distributions (reject H0)
#
#
# 5    sound
# Name: name, dtype: object
# 5    sound
# Name: name, dtype: object
# t-statistic=3.047, p=0.002
# Different distributions (reject H0)
#
#
# 6    hdr
# Name: name, dtype: object
# 6    hdr
# Name: name, dtype: object
# t-statistic=3.900, p=0.000
# Different distributions (reject H0)

# %%
# estimate sample size via power analysis
from statsmodels.stats.power import TTestIndPower
# parameters for power analysis
effect = 0.8
alpha = 0.05
power = 0.95
# perform power analysis
analysis = TTestIndPower()
result = analysis.solve_power(effect, power=power, nobs1=None, ratio=1.0, alpha=alpha)
print('Sample Size: %.3f' % result)
# Out:
# Sample Size: 41.594

# %%
effect_sizes = np.array([0.2, 0.5, 0.8])
sample_sizes = np.array(range(5, 150))
# calculate power curves from multiple power analyses
analysis = TTestIndPower()
analysis.plot_power(dep_var='nobs', nobs=sample_sizes, effect_size=effect_sizes)
plt.show()

# %%
for opa_idx, df_opa in enumerate(dfs_opa_pods):
    for no_opa_idx, df_no_opa in enumerate(dfs_no_opa_pods):
        if opa_idx == no_opa_idx:
            print(str(df_opa["name"].head(1)).split()[1])
            print("Means     {} {}".format(df_opa["startup"].mean(), df_no_opa["startup"].mean()))
            print("Difference: {}".format(df_opa["startup"].mean() - df_no_opa["startup"].mean()))
            #print("")
            #print("Std       {} {}".format(df_opa["startup"].std(), df_no_opa["startup"].std()))
            #print("Difference: {}".format(df_opa["startup"].std() - df_no_opa["startup"].std()))
            print("\n")
# Out:
# owner
# Means     7.445859872611465 7.22972972972973
# Difference: 0.2161301428817355
#
#
# vfx-1
# Means     8.173913043478262 7.026666666666666
# Difference: 1.1472463768115952
#
#
# vfx-2
# Means     8.22962962962963 7.513513513513513
# Difference: 0.7161161161161163
#
#
# vfx-3
# Means     8.451851851851853 7.438356164383562
# Difference: 1.013495687468291
#
#
# color
# Means     7.478599221789883 6.571428571428571
# Difference: 0.9071706503613122
#
#
# sound
# Means     7.8307692307692305 7.484848484848484
# Difference: 0.34592074592074606
#
#
# hdr
# Means     7.610294117647059 7.243636363636363
# Difference: 0.36665775401069567

# %%
low_bound_percent = 0.2161301428817355 / 7.445859872611465 * 100
high_bound_percent = 1.1472463768115952 / 8.173913043478262 * 100

print(low_bound_percent, high_bound_percent)
# Out:
# 2.9026888308325467 14.035460992907813
