# %%
import ast
import pandas as pd

opa_data = []
with open("wfs-opa-measures.dat", 'r') as f:
    for line in f:
        opa_data.append(ast.literal_eval(line))

# %%
no_opa_data = []
with open("wfs-no-opa-measures.dat", 'r') as f:
    for line in f:
        no_opa_data.append(ast.literal_eval(line))

# %%
df_opa = pd.DataFrame(opa_data, columns=['name', 'pod_scheduled', 'initialized', 'containers_ready', 'ready', 'startup'])
df_opa
# Out:
#      name         pod_scheduled           initialized      containers_ready  \
# 0   owner  2020-06-10T16:46:09Z  2020-06-10T16:46:11Z  2020-06-10T16:46:15Z
# 1   vfx-1  2020-06-10T16:46:14Z  2020-06-10T16:46:16Z  2020-06-10T16:46:23Z
# 2   vfx-2  2020-06-10T16:46:51Z  2020-06-10T16:46:54Z  2020-06-10T16:46:58Z
# 3   vfx-3  2020-06-10T16:47:32Z  2020-06-10T16:47:34Z  2020-06-10T16:47:40Z
# 4   color  2020-06-10T16:48:12Z  2020-06-10T16:48:14Z  2020-06-10T16:48:21Z
# ..    ...                   ...                   ...                   ...
# 90    hdr  2020-06-10T22:23:34Z  2020-06-10T22:23:36Z  2020-06-10T22:23:41Z
# 91  owner  2020-06-10T22:24:48Z  2020-06-10T22:24:50Z  2020-06-10T22:24:56Z
# 92  vfx-1  2020-06-10T22:24:52Z  2020-06-10T22:24:54Z  2020-06-10T22:24:59Z
# 93  vfx-2  2020-06-10T22:25:32Z  2020-06-10T22:25:34Z  2020-06-10T22:25:39Z
# 94  vfx-3  2020-06-10T22:26:11Z  2020-06-10T22:26:14Z  2020-06-10T22:26:19Z
#
#                    ready  startup
# ...

# %%
df_no_opa = pd.DataFrame(no_opa_data, columns=['name', 'pod_scheduled', 'initialized', 'containers_ready', 'ready', 'startup'])
df_no_opa
# Out:
#       name         pod_scheduled           initialized      containers_ready  \
# 0    owner  2020-06-10T22:47:08Z  2020-06-10T22:47:11Z  2020-06-10T22:47:15Z
# 1    vfx-1  2020-06-10T22:49:36Z  2020-06-10T22:49:39Z  2020-06-10T22:49:43Z
# 2    vfx-2  2020-06-10T22:50:58Z  2020-06-10T22:51:01Z  2020-06-10T22:51:06Z
# 3    vfx-3  2020-06-10T22:51:38Z  2020-06-10T22:51:41Z  2020-06-10T22:51:46Z
# 4    color  2020-06-10T22:41:43Z  2020-06-10T22:41:45Z  2020-06-10T22:41:50Z
# ..     ...                   ...                   ...                   ...
# 319  sound  2020-06-11T02:26:07Z  2020-06-11T02:26:10Z  2020-06-11T02:26:14Z
# 320    hdr  2020-06-11T02:26:43Z  2020-06-11T02:26:46Z  2020-06-11T02:26:51Z
# 321  color  2020-06-11T02:27:24Z  2020-06-11T02:27:26Z  2020-06-11T02:27:30Z
# 322  sound  2020-06-11T02:27:59Z  2020-06-11T02:28:01Z  2020-06-11T02:28:06Z
# 323    hdr  2020-06-11T02:28:35Z  2020-06-11T02:28:37Z  2020-06-11T02:28:43Z
#
#                     ready  startup
# ...

# %%
# Filters
is_owner = df_opa['name'] == "owner"
is_vfx_1 = df_opa['name'] == "vfx-1"
is_vfx_2 = df_opa['name'] == "vfx-2"
is_vfx_3 = df_opa['name'] == "vfx-3"
is_color = df_opa['name'] == "color"
is_sound = df_opa['name'] == "sound"
is_hdr   = df_opa['name'] == "hdr"

# Filtered dfs by pod
df_opa_owner = df_opa[is_owner]
df_opa_vfx_1 = df_opa[is_vfx_1]
df_opa_vfx_2 = df_opa[is_vfx_2]
df_opa_vfx_3 = df_opa[is_vfx_3]
df_opa_color = df_opa[is_color]
df_opa_sound = df_opa[is_sound]
df_opa_hdr   = df_opa[is_hdr]

dfs_opa_pods = [df_opa_owner, df_opa_vfx_1, df_opa_vfx_2, df_opa_vfx_3, df_opa_color, df_opa_sound, df_opa_hdr]

# %%
# Filters
is_owner = df_no_opa['name'] == "owner"
is_vfx_1 = df_no_opa['name'] == "vfx-1"
is_vfx_2 = df_no_opa['name'] == "vfx-2"
is_vfx_3 = df_no_opa['name'] == "vfx-3"
is_color = df_no_opa['name'] == "color"
is_sound = df_no_opa['name'] == "sound"
is_hdr   = df_no_opa['name'] == "hdr"

# Filtered dfs by pod
df_no_opa_owner = df_no_opa[is_owner]
df_no_opa_vfx_1 = df_no_opa[is_vfx_1]
df_no_opa_vfx_2 = df_no_opa[is_vfx_2]
df_no_opa_vfx_3 = df_no_opa[is_vfx_3]
df_no_opa_color = df_no_opa[is_color]
df_no_opa_sound = df_no_opa[is_sound]
df_no_opa_hdr   = df_no_opa[is_hdr]

dfs_no_opa_pods = [df_no_opa_owner, df_no_opa_vfx_1, df_no_opa_vfx_2, df_no_opa_vfx_3, df_no_opa_color, df_no_opa_sound, df_no_opa_hdr]

# %%
df_opa.describe()
# Out:
#          startup
# count  95.000000
# mean    7.757895
# std     0.975397
# min     5.000000
# 25%     7.000000
# 50%     8.000000
# 75%     8.000000
# max    10.000000

# %%
df_no_opa.describe()
# Out:
#           startup
# count  324.000000
# mean     7.114198
# std      1.002743
# min      5.000000
# 25%      6.000000
# 50%      7.000000
# 75%      8.000000
# max     10.000000

# %%
for df in dfs_opa_pods:
    print(df["name"].head(1))
    print(df.describe())
    print('\n')
# Out:
# 0    owner
# Name: name, dtype: object
#         startup
# count  14.00000
# mean    7.50000
# std     0.85485
# min     6.00000
# 25%     7.00000
# 50%     8.00000
# 75%     8.00000
# max     9.00000
#
#
# 1    vfx-1
# Name: name, dtype: object
#          startup
# count  14.000000
# mean    7.928571
# std     1.141139
# min     6.000000
# 25%     7.000000
# 50%     8.000000
# 75%     9.000000
# max    10.000000
#
#
# 2    vfx-2
# Name: name, dtype: object
#          startup
# count  14.000000
# mean    8.000000
# std     0.877058
# min     7.000000
# 25%     7.000000
# 50%     8.000000
# 75%     9.000000
# max     9.000000
#
#
# 3    vfx-3
# Name: name, dtype: object
#          startup
# count  14.000000
# mean    8.142857
# std     0.662994
# min     7.000000
# 25%     8.000000
# 50%     8.000000
# 75%     8.750000
# max     9.000000
#
#
# 4    color
# Name: name, dtype: object
#          startup
# count  13.000000
# mean    7.384615
# std     1.260850
# min     5.000000
# ...

# %%
for df in dfs_no_opa_pods:
    print(df["name"].head(1))
    print(df.describe())
    print('\n')
# Out:
# 0    owner
# Name: name, dtype: object
#          startup
# count  37.000000
# mean    7.351351
# std     0.789381
# min     6.000000
# 25%     7.000000
# 50%     7.000000
# 75%     8.000000
# max     9.000000
#
#
# 1    vfx-1
# Name: name, dtype: object
#          startup
# count  37.000000
# mean    6.891892
# std     1.021540
# min     5.000000
# 25%     6.000000
# 50%     7.000000
# 75%     7.000000
# max     9.000000
#
#
# 2    vfx-2
# Name: name, dtype: object
#          startup
# count  37.000000
# mean    7.243243
# std     0.925125
# min     5.000000
# 25%     7.000000
# 50%     7.000000
# 75%     8.000000
# max     9.000000
#
#
# 3    vfx-3
# Name: name, dtype: object
#          startup
# count  37.000000
# mean    7.432432
# std     0.987155
# min     6.000000
# 25%     7.000000
# 50%     7.000000
# 75%     8.000000
# max    10.000000
#
#
# 4    color
# Name: name, dtype: object
#          startup
# count  65.000000
# mean    6.584615
# std     0.966506
# min     5.000000
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
from pylab import rcParams
from scipy.stats import f_oneway
from scipy.stats import ttest_ind

# %matplotlib inline
warnings.filterwarnings("ignore")
rcParams['figure.figsize'] = 20,10
rcParams['font.size'] = 30
sns.set()
np.random.seed(8)

# %%
def plot_distribution(inp):
    plt.figure()
    ax = sns.distplot(inp)
    plt.axvline(np.mean(inp), color="k", linestyle="dashed", linewidth=5)
    _, max_ = plt.ylim()
    plt.text(
        inp.mean() + inp.mean() / 10,
        max_ - max_ / 10,
        "Mean: {:.2f}".format(inp.mean()),
    )
    return plt.figure

# %%
plot_distribution(df_opa["startup"])
plot_distribution(df_no_opa["startup"])
# Out:
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
plt.figure()
ax1 = sns.distplot(df_opa["startup"])
ax2 = sns.distplot(df_no_opa["startup"])
plt.axvline(np.mean(df_opa["startup"]), color='b', linestyle='dashed', linewidth=5)
plt.axvline(np.mean(df_no_opa["startup"]), color='orange', linestyle='dashed', linewidth=5)

# %%
for opa_idx, df_opa in enumerate(dfs_opa_pods):
    for no_opa_idx, df_no_opa in enumerate(dfs_no_opa_pods):
        if opa_idx == no_opa_idx:
            print(df_opa["name"].head(1))
            print(df_no_opa["name"].head(1))
            plt.figure()
            ax1 = sns.distplot(df_opa["startup"])
            ax2 = sns.distplot(df_no_opa["startup"])
            plt.axvline(np.mean(df_opa["startup"]), color='b', linestyle='dashed', linewidth=5)
            plt.axvline(np.mean(df_no_opa["startup"]), color='orange', linestyle='dashed', linewidth=5)
# Out:
# 0    owner
# Name: name, dtype: object
# 0    owner
# Name: name, dtype: object
# 1    vfx-1
# Name: name, dtype: object
# 1    vfx-1
# Name: name, dtype: object
# 2    vfx-2
# Name: name, dtype: object
# 2    vfx-2
# Name: name, dtype: object
# 3    vfx-3
# Name: name, dtype: object
# 3    vfx-3
# Name: name, dtype: object
# 4    color
# Name: name, dtype: object
# 4    color
# Name: name, dtype: object
# 5    sound
# Name: name, dtype: object
# 5    sound
# Name: name, dtype: object
# 6    hdr
# Name: name, dtype: object
# 6    hdr
# Name: name, dtype: object

# %%
def t_test(arr_1, arr_2, alpha, sample_size):
    stat, p = ttest_ind(arr_1, arr_2)
    print('t-statistic=%.3f, p=%.3f' % (stat, p))
    if p > alpha:
        print('Same distributions (fail to reject H0)')
    else:
        print('Different distributions (reject H0)')

# %%
t_test(df_opa["startup"], df_no_opa["startup"], alpha, N)

for opa_idx, df_opa in enumerate(dfs_opa_pods):
    for no_opa_idx, df_no_opa in enumerate(dfs_no_opa_pods):
        if opa_idx == no_opa_idx:
            print(df_opa["name"].head(1))
            print(df_no_opa["name"].head(1))
            t_test(df_opa["startup"], df_no_opa["startup"], alpha, N)
            print('\n')
# Out:
# t-statistic=0.872, p=0.386
# Same distributions (fail to reject H0)
# 0    owner
# Name: name, dtype: object
# 0    owner
# Name: name, dtype: object
# t-statistic=0.587, p=0.560
# Same distributions (fail to reject H0)
# 1    vfx-1
# Name: name, dtype: object
# 1    vfx-1
# Name: name, dtype: object
# t-statistic=3.133, p=0.003
# Different distributions (reject H0)
# 2    vfx-2
# Name: name, dtype: object
# 2    vfx-2
# Name: name, dtype: object
# t-statistic=2.643, p=0.011
# Different distributions (reject H0)
# 3    vfx-3
# Name: name, dtype: object
# 3    vfx-3
# Name: name, dtype: object
# t-statistic=2.481, p=0.017
# Different distributions (reject H0)
# 4    color
# Name: name, dtype: object
# 4    color
# Name: name, dtype: object
# t-statistic=2.585, p=0.012
# Different distributions (reject H0)
# 5    sound
# Name: name, dtype: object
# 5    sound
# Name: name, dtype: object
# t-statistic=1.540, p=0.129
# Same distributions (fail to reject H0)
# 6    hdr
# ...

# %%
# estimate sample size via power analysis
from statsmodels.stats.power import TTestIndPower
# parameters for power analysis
effect = 0.8
alpha = 0.05
power = 0.90
# perform power analysis
analysis = TTestIndPower()
result = analysis.solve_power(effect, power=power, nobs1=None, ratio=1.0, alpha=alpha)
print('Sample Size: %.3f' % result)
# Out:
# Sample Size: 33.826

# %%
effect_sizes = np.array([0.2, 0.5, 0.8])
sample_sizes = np.array(range(5, 150))
# calculate power curves from multiple power analyses
analysis = TTestIndPower()
analysis.plot_power(dep_var='nobs', nobs=sample_sizes, effect_size=effect_sizes)
plt.show()
